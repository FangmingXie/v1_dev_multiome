# %% [markdown]
# # Inputs
# ---

# %%
import numpy as np, zarr, nrrd
# alignment functions
from bigstream.align import alignment_pipeline
from bigstream.transform import apply_transform
import tifffile

import seaborn as sns
import matplotlib.pyplot as plt

# %%
p = '/u/home/f/f7xiesnm/project-zipursky/data/hold/easi002_2_r1/'
outdir = '/u/home/f/f7xiesnm/project-zipursky/easifish/results/viz_easi002_2_r1'
# !mkdir -p $outdir

# %%
r1_path = p + '/r1_export.n5'
r1_zarr = zarr.open(store=zarr.N5Store(r1_path), mode='r')

# %%
for c in ['c0', 'c1', 'c2', 'c3', 'c4']:
    r1 = r1_zarr[f'/{c}/s4'] 
    print(np.max(r1), np.min(r1))
    tifffile.imwrite(outdir+f'/r1_c{c}_s4.tiff', r1)

# %%
16*16*8
