# %%
import napari

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
ddir = '/u/home/f/f7xiesnm/project-zipursky/easifish/p28nr2_sap3/outputs/r2'
# !ls $ddir

f1 = os.path.join(ddir, 'spots/spots_c0.txt')
f2 = os.path.join(ddir, 'spots/spots_c1.txt')
f3 = os.path.join(ddir, 'spots/spots_c2.txt')
f4 = os.path.join(ddir, 'spots/spots_c4.txt')


fsum = os.path.join(ddir, 'assignments/count.csv')
# Out:
# assignments  intensities  segmentation	spots  stitching

# %%
cns = [
    'Arc',
    'Gria3',
    'Fos',
    'Nr4a3',
]

# %%
df = pd.read_csv(fsum, index_col=0)
df.columns = cns

df
# Out:
#         Arc  Gria3   Fos  Nr4a3
# 1      44.0   37.0  19.0   25.0
# 2      20.0   34.0   7.0   13.0
# 3      40.0   27.0  10.0   21.0
# 4      65.0   44.0  24.0   30.0
# 5      17.0   41.0   9.0    7.0
# ...     ...    ...   ...    ...
# 16728   4.0    0.0   0.0    2.0
# 16729   0.0    0.0   1.0    0.0
# 16730   9.0   13.0   3.0    0.0
# 16731   5.0    5.0   3.0    3.0
# 16732   3.0    0.0   2.0    1.0
#
# [16732 rows x 4 columns]

# %%
sns.histplot(df['Gria3'])
# Out:
# <Axes: xlabel='Gria3', ylabel='Count'>

# %%
df1 = pd.read_csv(f1, header=None) # x y z in micron
df2 = pd.read_csv(f2, header=None) # x y z in micron
df3 = pd.read_csv(f3, header=None) # x y z in micron
df4 = pd.read_csv(f4, header=None) # x y z in micron
df1
# Out:
#                   0            1           2         3
# 0        345.626664    36.756255   21.671957  130.7591
# 1        767.703996    11.612516    6.812106  176.7754
# 2        777.990102     4.451650   21.928913  172.5951
# 3        344.192890   106.479238   17.682965  139.9123
# 4        515.180275   193.442976   23.428523  216.0940
# ...             ...          ...         ...       ...
# 762922  1108.372642  2045.153781  696.269510  383.9332
# 762923  1121.739598  2048.995701  687.870351  136.7658
# 762924  1133.329989  2048.163239  697.053650  169.1018
# 762925  1139.371813  2053.063665  683.072565  156.4188
# 762926  1133.581885  2056.756315  696.269510  130.8450
#
# [762927 rows x 4 columns]

# %%
def plot0(df):
    fig, axs = plt.subplots(1,4,figsize=(4*4,1*4))
    ax = axs[0]
    sns.histplot(df[0], kde=False, ax=ax)
    ax = axs[1]
    sns.histplot(df[1], kde=False, ax=ax)
    ax = axs[2]
    sns.histplot(df[2], kde=False, ax=ax)
    ax = axs[3]
    sns.histplot(df[3], kde=False, ax=ax)

# %%
plot0(df1)
plot0(df2)
plot0(df3)
plot0(df4)

# %%
fig, axs = plt.subplots(2,2, figsize=(2*4,2*4))
ax = axs.flat[0]
sns.scatterplot(data=df1.sample(frac=0.1), x=0, y=1, s=5, edgecolor='none', label=cns[0], ax=ax)
ax = axs.flat[1]
sns.scatterplot(data=df2.sample(frac=0.1), x=0, y=1, s=5, edgecolor='none', label=cns[1], ax=ax)
ax = axs.flat[2]
sns.scatterplot(data=df3.sample(frac=0.1), x=0, y=1, s=5, edgecolor='none', label=cns[2], ax=ax)
ax = axs.flat[3]
sns.scatterplot(data=df4.sample(frac=0.1), x=0, y=1, s=5, edgecolor='none', label=cns[3], ax=ax)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
sns.scatterplot(data=df3, x=0, y=2, s=5, edgecolor='none', label=cns[0])
# Out:
# <Axes: xlabel='0', ylabel='2'>
