# %% [markdown]
# # Inputs
# ---

# %%
import numpy as np, zarr, nrrd
# alignment functions
from bigstream.align import alignment_pipeline
from bigstream.transform import apply_transform
import tifffile

import seaborn as sns
import matplotlib.pyplot as plt

# %%
p = '/u/home/f/f7xiesnm/project-zipursky/easifish/lt186/outputs/'
outdir = '/u/home/f/f7xiesnm/project-zipursky/easifish/results/test_bigstream_lt186_cap_v3'
# !mkdir -p $outdir

# %%
r1_path = p + '/r1/stitching/export.n5'
r2_path = p + '/r2/stitching/export.n5'
r6_path = p + '/r6/stitching/export.n5'
r7_path = p + '/r7/stitching/export.n5'

r1_zarr = zarr.open(store=zarr.N5Store(r1_path), mode='r')
r2_zarr = zarr.open(store=zarr.N5Store(r2_path), mode='r')
r6_zarr = zarr.open(store=zarr.N5Store(r6_path), mode='r')
r7_zarr = zarr.open(store=zarr.N5Store(r7_path), mode='r')

r1 = r1_zarr['/c3/s4'][...]
r2 = r2_zarr['/c3/s4'][...]
r6 = r6_zarr['/c3/s4'][...]
r7 = r7_zarr['/c3/s4'][...]

# %%
np.max(r1), np.max(r2), np.max(r6), np.max(r7)
# Out:
# (61957, 47284, 63646, 56672)

# %%
th = np.percentile(r1, 99.9)
r1[r1>th] = th

th = np.percentile(r2, 99.9)
r2[r2>th] = th

th = np.percentile(r6, 99.9)
r6[r6>th] = th

th = np.percentile(r7, 99.9)
r7[r7>th] = th

# %%
np.max(r1), np.max(r2), np.max(r6), np.max(r7)
# Out:
# (167, 239, 192, 178)

# %%
# tifffile.imwrite(outdir+'/r1.tiff', r1)
# tifffile.imwrite(outdir+'/r2.tiff', r2)
# tifffile.imwrite(outdir+'/r6.tiff', r6)
# tifffile.imwrite(outdir+'/r7.tiff', r7)

# %%
mov_path = r6_path
fix_path = r2_path

mov = r6
fix = r2

output_mat = outdir+'/affine_r6tor2.mat'
output_tif = outdir+'/affine_r6tor2.tiff'

# %%
exp_factor = 2  # replace this with the known expansion factor for your sample to use pre-expansion units

s1_scale = [1,2,2] # z,y,x
s3_scale = [4,8,8]
s4_scale = [9,16,16]

# load fix data and spacing
fix_zarr = zarr.open(store=zarr.N5Store(fix_path), mode='r')
fix_meta = fix_zarr.attrs.asdict()
fix_spacing = np.array(fix_meta['pixelResolution']['dimensions'][::-1]) / exp_factor
fix_spacing_s1 = fix_spacing * s1_scale 
fix_spacing_s3 = fix_spacing * s3_scale 
fix_spacing_s4 = fix_spacing * s4_scale 

# load mov data and spacing
mov_zarr = zarr.open(store=zarr.N5Store(mov_path), mode='r')
mov_meta = mov_zarr.attrs.asdict()
mov_spacing = np.array(mov_meta['pixelResolution']['dimensions'][::-1]) / exp_factor
mov_spacing_s1 = mov_spacing * s1_scale
mov_spacing_s3 = mov_spacing * s3_scale 
mov_spacing_s4 = mov_spacing * s4_scale 

# print spacings
print(fix_spacing, mov_spacing)
print(fix_spacing_s1, mov_spacing_s1)
print(fix_spacing_s3, mov_spacing_s3)
print(fix_spacing_s4, mov_spacing_s4)

# print shapes
print(fix_zarr['/c3/s0'].shape, mov_zarr['/c3/s0'].shape)
print(fix_zarr['/c3/s3'].shape, mov_zarr['/c3/s3'].shape)
print(fix_zarr['/c3/s4'].shape, mov_zarr['/c3/s4'].shape)
# Out:
# [0.21  0.115 0.115] [0.21  0.115 0.115]
# [0.21 0.23 0.23] [0.21 0.23 0.23]
# [0.84 0.92 0.92] [0.84 0.92 0.92]
# [1.89 1.84 1.84] [1.89 1.84 1.84]
# (2258, 7348, 9045) (2498, 7414, 9085)
# (564, 918, 1130) (624, 926, 1135)
# (250, 459, 565) (277, 463, 567)

# %% [markdown]
# # Alignment
# ---

# %% [markdown]
# ### global

# %%
# alignment functions
from bigstream.align import alignment_pipeline
from bigstream.transform import apply_transform

# %%
# define alignment steps
ransac_kwargs = {
    'blob_sizes':[2, 8],
    'cc_radius':12,
    'match_threshold':0.9, # 0.4,
    'nspots':2000,         # 10000,
}

affine_kwargs = {
    'alignment_spacing':4.0,
    'shrink_factors':(1,),
    'smooth_sigmas':(4.,),
    'optimizer_args':{
        'learningRate':0.25,
        'minStep':0.,
        'numberOfIterations':400,
    },
    'metric':'C',
}


steps = [
    ('ransac', ransac_kwargs,),
    ('affine', affine_kwargs,),
]

# %%
# %%time


# align
affine = alignment_pipeline(
    fix, mov,
    fix_spacing_s4,
    mov_spacing_s4,
    steps,
    # fix_mask=fix_mask,
    # mov_mask=mov_mask,
)

# apply affine only
affine_aligned = apply_transform(
    fix, mov,
    fix_spacing_s4, mov_spacing_s4,
    transform_list=[affine,],
)

# write results
np.savetxt(output_mat, affine)
tifffile.imwrite(output_tif, affine_aligned)
# Out:
# computing fixed spots
# found 70066 fixed spots
# computing moving spots
# found 97759 moving spots
# sorting spots
# extracting contexts
# computing pairwise correlations
# 3 matched spots
# insufficient point matches found, returning default
# LEVEL:  0  ITERATION:  0  METRIC:  -0.14866955024888373
# LEVEL:  0  ITERATION:  1  METRIC:  -0.1518747997802
# LEVEL:  0  ITERATION:  2  METRIC:  -0.15470995330223297
# LEVEL:  0  ITERATION:  3  METRIC:  -0.15715358414032984
# LEVEL:  0  ITERATION:  4  METRIC:  -0.15918775124554255
# LEVEL:  0  ITERATION:  5  METRIC:  -0.160798168758582
# LEVEL:  0  ITERATION:  6  METRIC:  -0.1619743405103614
# LEVEL:  0  ITERATION:  7  METRIC:  -0.16270965081057556
# LEVEL:  0  ITERATION:  8  METRIC:  -0.1630698901900996
# LEVEL:  0  ITERATION:  9  METRIC:  -0.16366107123570584
# LEVEL:  0  ITERATION:  10  METRIC:  -0.16470644688625619
# LEVEL:  0  ITERATION:  11  METRIC:  -0.1659111934199007
# LEVEL:  0  ITERATION:  12  METRIC:  -0.16719062770603274
# LEVEL:  0  ITERATION:  13  METRIC:  -0.16840369544426181
# LEVEL:  0  ITERATION:  14  METRIC:  -0.16938207844282904
# LEVEL:  0  ITERATION:  15  METRIC:  -0.17007097041772742
# LEVEL:  0  ITERATION:  16  METRIC:  -0.1707019201964058
# LEVEL:  0  ITERATION:  17  METRIC:  -0.1716138438226224
# LEVEL:  0  ITERATION:  18  METRIC:  -0.17285733324831487
# LEVEL:  0  ITERATION:  19  METRIC:  -0.17433029873570516
# LEVEL:  0  ITERATION:  20  METRIC:  -0.17590615054417982
# LEVEL:  0  ITERATION:  21  METRIC:  -0.17743926477907992
# LEVEL:  0  ITERATION:  22  METRIC:  -0.17881685417510995
# LEVEL:  0  ITERATION:  208  METRIC:  -0.5058542934290483
# LEVEL:  0  ITERATION:  209  METRIC:  -0.5085044862256839
# LEVEL:  0  ITERATION:  210  METRIC:  -0.5111504904398942
# LEVEL:  0  ITERATION:  211  METRIC:  -0.5137654166759532
# LEVEL:  0  ITERATION:  212  METRIC:  -0.5163769134794955
# LEVEL:  0  ITERATION:  213  METRIC:  -0.5189830241996611
# LEVEL:  0  ITERATION:  214  METRIC:  -0.5216017182008235
# LEVEL:  0  ITERATION:  215  METRIC:  -0.5242019029487794
# LEVEL:  0  ITERATION:  216  METRIC:  -0.5267789176763592
# LEVEL:  0  ITERATION:  217  METRIC:  -0.5293127011537325
# LEVEL:  0  ITERATION:  218  METRIC:  -0.531799834880701
# LEVEL:  0  ITERATION:  219  METRIC:  -0.534229968150931
# LEVEL:  0  ITERATION:  220  METRIC:  -0.5365984450875485
# LEVEL:  0  ITERATION:  221  METRIC:  -0.5389051018664305
# LEVEL:  0  ITERATION:  222  METRIC:  -0.5411500668807253
# LEVEL:  0  ITERATION:  223  METRIC:  -0.5433205694253964
# LEVEL:  0  ITERATION:  224  METRIC:  -0.5454081334552785
# LEVEL:  0  ITERATION:  225  METRIC:  -0.5473932270206825
# LEVEL:  0  ITERATION:  226  METRIC:  -0.549278572146887
# LEVEL:  0  ITERATION:  227  METRIC:  -0.5510465279531048
# LEVEL:  0  ITERATION:  228  METRIC:  -0.5526913686836112
# LEVEL:  0  ITERATION:  229  METRIC:  -0.5541970342363101
# LEVEL:  0  ITERATION:  230  METRIC:  -0.5555715829514076
# LEVEL:  0  ITERATION:  231  METRIC:  -0.5568424141562275
# LEVEL:  0  ITERATION:  232  METRIC:  -0.5579926595665903
# LEVEL:  0  ITERATION:  233  METRIC:  -0.559027092372808
# LEVEL:  0  ITERATION:  234  METRIC:  -0.5599552234085392
# LEVEL:  0  ITERATION:  235  METRIC:  -0.5607941289783241
# LEVEL:  0  ITERATION:  236  METRIC:  -0.5615540171654322
# LEVEL:  0  ITERATION:  237  METRIC:  -0.5622490002003057
# LEVEL:  0  ITERATION:  238  METRIC:  -0.5628827187637546
# LEVEL:  0  ITERATION:  239  METRIC:  -0.5634591164092798
# LEVEL:  0  ITERATION:  240  METRIC:  -0.5639540177277986
# LEVEL:  0  ITERATION:  241  METRIC:  -0.5643680486720289
# LEVEL:  0  ITERATION:  242  METRIC:  -0.5646308059162441
# LEVEL:  0  ITERATION:  243  METRIC:  -0.564798227579506
# LEVEL:  0  ITERATION:  244  METRIC:  -0.5648857825340842
# LEVEL:  0  ITERATION:  245  METRIC:  -0.5649885516842463
# LEVEL:  0  ITERATION:  246  METRIC:  -0.5650975254295608
# LEVEL:  0  ITERATION:  247  METRIC:  -0.5652078182138339
# LEVEL:  0  ITERATION:  248  METRIC:  -0.5653182687707805
# LEVEL:  0  ITERATION:  249  METRIC:  -0.5654285360132417
# LEVEL:  0  ITERATION:  250  METRIC:  -0.56553955315496
# LEVEL:  0  ITERATION:  251  METRIC:  -0.5656496564130286
# LEVEL:  0  ITERATION:  252  METRIC:  -0.5657606223672441
# LEVEL:  0  ITERATION:  253  METRIC:  -0.5658732672530973
# LEVEL:  0  ITERATION:  254  METRIC:  -0.5659878812671669
# LEVEL:  0  ITERATION:  255  METRIC:  -0.5661038969711228
# LEVEL:  0  ITERATION:  256  METRIC:  -0.5662223481149875
# LEVEL:  0  ITERATION:  257  METRIC:  -0.5663421461127414
# LEVEL:  0  ITERATION:  258  METRIC:  -0.5664610166078746
# LEVEL:  0  ITERATION:  259  METRIC:  -0.5665802350789055
# LEVEL:  0  ITERATION:  260  METRIC:  -0.5666988627241665
# LEVEL:  0  ITERATION:  261  METRIC:  -0.5668190489437939
# LEVEL:  0  ITERATION:  262  METRIC:  -0.5669437174666444
# LEVEL:  0  ITERATION:  263  METRIC:  -0.5670731724169316
# LEVEL:  0  ITERATION:  264  METRIC:  -0.5672092323454887
# LEVEL:  0  ITERATION:  265  METRIC:  -0.5673500693843431
# LEVEL:  0  ITERATION:  266  METRIC:  -0.567496039923019
# LEVEL:  0  ITERATION:  267  METRIC:  -0.5676475831167261
# LEVEL:  0  ITERATION:  268  METRIC:  -0.5678060923713996
# LEVEL:  0  ITERATION:  269  METRIC:  -0.5679686639431315
# LEVEL:  0  ITERATION:  270  METRIC:  -0.5681398136837224
# LEVEL:  0  ITERATION:  271  METRIC:  -0.5683218564237309
# LEVEL:  0  ITERATION:  272  METRIC:  -0.5685190565779414
# LEVEL:  0  ITERATION:  273  METRIC:  -0.5687310234330982
# LEVEL:  0  ITERATION:  274  METRIC:  -0.5689560967887917
# LEVEL:  0  ITERATION:  275  METRIC:  -0.5691898317431646
# LEVEL:  0  ITERATION:  276  METRIC:  -0.5694330775605302
# LEVEL:  0  ITERATION:  277  METRIC:  -0.5696900559813171
# LEVEL:  0  ITERATION:  278  METRIC:  -0.5699614541204311
# LEVEL:  0  ITERATION:  279  METRIC:  -0.5702497913247953
# LEVEL:  0  ITERATION:  280  METRIC:  -0.5705584603835538
# LEVEL:  0  ITERATION:  281  METRIC:  -0.5708926523124329
# LEVEL:  0  ITERATION:  282  METRIC:  -0.5712491863413213
# LEVEL:  0  ITERATION:  283  METRIC:  -0.5716198137957755
# LEVEL:  0  ITERATION:  284  METRIC:  -0.5720091353750307
# LEVEL:  0  ITERATION:  285  METRIC:  -0.5724097635840572
# LEVEL:  0  ITERATION:  286  METRIC:  -0.5728132820945543
# LEVEL:  0  ITERATION:  287  METRIC:  -0.5732193685885567
# LEVEL:  0  ITERATION:  288  METRIC:  -0.5736248397326718
# LEVEL:  0  ITERATION:  289  METRIC:  -0.5740334320744864
# LEVEL:  0  ITERATION:  290  METRIC:  -0.5744437794754859
# LEVEL:  0  ITERATION:  291  METRIC:  -0.5748523840290072
# LEVEL:  0  ITERATION:  292  METRIC:  -0.5752594703368719
# LEVEL:  0  ITERATION:  293  METRIC:  -0.5756605858279489
# LEVEL:  0  ITERATION:  294  METRIC:  -0.5760533672388664
# LEVEL:  0  ITERATION:  295  METRIC:  -0.5764364899424298
# LEVEL:  0  ITERATION:  296  METRIC:  -0.5768096488491784
# LEVEL:  0  ITERATION:  297  METRIC:  -0.5771692213396217
# LEVEL:  0  ITERATION:  298  METRIC:  -0.5775113531637999
# LEVEL:  0  ITERATION:  299  METRIC:  -0.5778395707017367
# LEVEL:  0  ITERATION:  300  METRIC:  -0.5781528841254858
# LEVEL:  0  ITERATION:  301  METRIC:  -0.5784567991261912
# LEVEL:  0  ITERATION:  302  METRIC:  -0.5787645895022772
# LEVEL:  0  ITERATION:  303  METRIC:  -0.5790697451084652
# LEVEL:  0  ITERATION:  304  METRIC:  -0.579377988155732
# LEVEL:  0  ITERATION:  305  METRIC:  -0.5796767580934036
# LEVEL:  0  ITERATION:  306  METRIC:  -0.5799885443675619
# LEVEL:  0  ITERATION:  307  METRIC:  -0.580284857013658
# LEVEL:  0  ITERATION:  308  METRIC:  -0.5806085342928706
# LEVEL:  0  ITERATION:  309  METRIC:  -0.5808607500999854
# LEVEL:  0  ITERATION:  310  METRIC:  -0.5811555131936303
# LEVEL:  0  ITERATION:  311  METRIC:  -0.5813031746420326
# LEVEL:  0  ITERATION:  312  METRIC:  -0.5815636030417743
# LEVEL:  0  ITERATION:  313  METRIC:  -0.5816280706347983
# LEVEL:  0  ITERATION:  314  METRIC:  -0.5817227272913039
# LEVEL:  0  ITERATION:  315  METRIC:  -0.581858713295375
# LEVEL:  0  ITERATION:  316  METRIC:  -0.5819752355956902
# LEVEL:  0  ITERATION:  317  METRIC:  -0.5821036918616007
# LEVEL:  0  ITERATION:  318  METRIC:  -0.5822154167692597
# LEVEL:  0  ITERATION:  319  METRIC:  -0.5823381826339564
# LEVEL:  0  ITERATION:  320  METRIC:  -0.5824417960330959
# LEVEL:  0  ITERATION:  321  METRIC:  -0.5825603252254008
# LEVEL:  0  ITERATION:  322  METRIC:  -0.5826513866349116
# LEVEL:  0  ITERATION:  323  METRIC:  -0.5827657592089978
# LEVEL:  0  ITERATION:  324  METRIC:  -0.5828377676560871
# LEVEL:  0  ITERATION:  325  METRIC:  -0.5829455881042265
# LEVEL:  0  ITERATION:  326  METRIC:  -0.582999307535921
# LEVEL:  0  ITERATION:  327  METRIC:  -0.5831017112806229
# LEVEL:  0  ITERATION:  328  METRIC:  -0.5831486651662567
# LEVEL:  0  ITERATION:  329  METRIC:  -0.5832451815838348
# LEVEL:  0  ITERATION:  330  METRIC:  -0.5832847343776704
# LEVEL:  0  ITERATION:  331  METRIC:  -0.5833755698633464
# LEVEL:  0  ITERATION:  332  METRIC:  -0.5834098639889013
# LEVEL:  0  ITERATION:  333  METRIC:  -0.5834931187705272
# LEVEL:  0  ITERATION:  334  METRIC:  -0.5835218203215421
# LEVEL:  0  ITERATION:  335  METRIC:  -0.5836043908447227
# LEVEL:  0  ITERATION:  336  METRIC:  -0.5836313416124177
# LEVEL:  0  ITERATION:  337  METRIC:  -0.5836582153941735
# LEVEL:  0  ITERATION:  338  METRIC:  -0.5836662147220751
# LEVEL:  0  ITERATION:  339  METRIC:  -0.5836758507310337
# LEVEL:  0  ITERATION:  340  METRIC:  -0.5836898502449691
# LEVEL:  0  ITERATION:  341  METRIC:  -0.5837059919334777
# Registration succeeded
# CPU times: user 31min 29s, sys: 37.1 s, total: 32min 6s
# Wall time: 5min 56s

# %%
affine[:3,3]
# Out:
# array([49.5186445 ,  0.78555774,  7.59431649])

# %%
sns.heatmap(affine[:3,:3] - np.eye(3))
plt.show()
sns.heatmap(affine[:3, 3].reshape(-1,1))
plt.show()
