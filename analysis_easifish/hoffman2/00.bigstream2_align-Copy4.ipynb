# %% [markdown]
# # Inputs
# ---

# %%
import numpy as np, zarr, nrrd
# alignment functions
from bigstream.align import alignment_pipeline
from bigstream.transform import apply_transform
import tifffile

# %%
p = '/u/home/f/f7xiesnm/project-zipursky/easifish/lt185/outputs/'
outdir = '/u/home/f/f7xiesnm/project-zipursky/easifish/results/test_bigstream3'
# !mkdir -p $outdir

# %%
fix_path = p + '/r1/stitching/export.n5'
mov_path = p + '/r2/stitching/export.n5'
exp_factor = 2  # replace this with the known expansion factor for your sample to use pre-expansion units

s1_scale = [1,2,2] # z,y,x
s3_scale = [4,8,8]
s4_scale = [8,16,16]

# load fix data and spacing
fix_zarr = zarr.open(store=zarr.N5Store(fix_path), mode='r')
fix_meta = fix_zarr.attrs.asdict()
fix_spacing = np.array(fix_meta['pixelResolution']['dimensions'][::-1]) / exp_factor
fix_spacing_s1 = fix_spacing * s1_scale 
fix_spacing_s3 = fix_spacing * s3_scale 
fix_spacing_s4 = fix_spacing * s4_scale 

# load mov data and spacing
mov_zarr = zarr.open(store=zarr.N5Store(mov_path), mode='r')
mov_meta = mov_zarr.attrs.asdict()
mov_spacing = np.array(mov_meta['pixelResolution']['dimensions'][::-1]) / exp_factor
mov_spacing_s1 = mov_spacing * s1_scale
mov_spacing_s3 = mov_spacing * s3_scale 
mov_spacing_s4 = mov_spacing * s4_scale 

# print spacings
print(fix_spacing, mov_spacing)
print(fix_spacing_s1, mov_spacing_s1)
print(fix_spacing_s3, mov_spacing_s3)
print(fix_spacing_s4, mov_spacing_s4)

# print shapes
print(fix_zarr['/c3/s0'].shape, mov_zarr['/c3/s0'].shape)
print(fix_zarr['/c3/s3'].shape, mov_zarr['/c3/s3'].shape)
print(fix_zarr['/c3/s4'].shape, mov_zarr['/c3/s4'].shape)

# # write some channels
# nrrd.write(outdir+'/fix.nrrd', fix_zarr['/c3/s4'][...].transpose(2,1,0), compression_level=2)
# nrrd.write(outdir+'/mov.nrrd', mov_zarr['/c3/s4'][...].transpose(2,1,0), compression_level=2)
# Out:
# [0.21  0.115 0.115] [0.21  0.115 0.115]
# [0.21 0.23 0.23] [0.21 0.23 0.23]
# [0.84 0.92 0.92] [0.84 0.92 0.92]
# [1.68 1.84 1.84] [1.68 1.84 1.84]
# (2921, 7310, 9092) (2745, 7350, 9173)
# (730, 913, 1136) (686, 918, 1146)
# (324, 456, 568) (305, 459, 573)

# %% [markdown]
# # Alignment
# ---

# %% [markdown]
# ### global

# %%
# alignment functions
from bigstream.align import alignment_pipeline
from bigstream.transform import apply_transform

# %%
# get global alignment channels
fix = fix_zarr['/c3/s4'][...]
mov = mov_zarr['/c3/s4'][...][:, ::-1, ::-1]  # moving image data is 180 degrees rotates about z axis

# create some masks to focus alignment only on planes below the large artifact at the top
fix_mask = np.ones(fix.shape, dtype=np.uint8)
fix_mask[:65] = 0
fix_mask[-40:] = 0

mov_mask = np.ones(mov.shape, dtype=np.uint8)
mov_mask[:45] = 0
mov_mask[-40:] = 0

# %%
mov0 = mov_zarr['/c3/s4'][...] #[:, ::-1, ::-1]  # moving image data is 180 degrees rotates about z axis

# %%
mov1 = mov_zarr['/c3/s4'][...][:, ::-1, ::-1]  # moving image data is 180 degrees rotates about z axis

# %%
# tifffile.imwrite(outdir+'/fix.tiff', fix.transpose([2,1,0]))
# tifffile.imwrite(outdir+'/mov.tiff', mov.transpose([2,1,0]))
# tifffile.imwrite(outdir+'/mov0.tiff', mov0.transpose([2,1,0]))

# %%
mov0.shape
# Out:
# (305, 459, 573)

# %%
# %%time

# define alignment steps
ransac_kwargs = {
    'blob_sizes':[2, 8],
    # 'cc_radius':12,
    # 'match_threshold':0.4,
    'nspots':10000,
}

affine_kwargs = {
    'alignment_spacing':4.0,
    'shrink_factors':(1,),
    'smooth_sigmas':(4.,),
    'optimizer_args':{
        'learningRate':0.25,
        'minStep':0.,
        'numberOfIterations':400,
    },
    'metric':'C',
}


steps = [('ransac', ransac_kwargs,),
         ('affine', affine_kwargs,),]

# align
affine0 = alignment_pipeline(
    fix, mov0,
    fix_spacing_s4,
    mov_spacing_s4,
    steps,
    # fix_mask=fix_mask,
    # mov_mask=mov_mask,
)

# apply affine only
affine_aligned0 = apply_transform(
    fix, mov0,
    fix_spacing_s4, mov_spacing_s4,
    transform_list=[affine0,],
)

# write results
np.savetxt(outdir+'/affine0-v2.mat', affine0)
# nrrd.write(outdir+'/affine.nrrd', affine_aligned.transpose(2,1,0), compression_level=2)
tifffile.imwrite(outdir+'/affine0-v2.tiff', affine_aligned0.transpose([2,1,0]))

# # load precomputed results
# affine = np.loadtxt(outdir+'/affine.mat')
# Out:
# computing fixed spots
# found 22 fixed spots
# insufficient fixed spots found, returning default
# LEVEL:  0  ITERATION:  0  METRIC:  -0.2022174145234939
# LEVEL:  0  ITERATION:  1  METRIC:  -0.20511071671633793
# LEVEL:  0  ITERATION:  2  METRIC:  -0.20767933571249472
# LEVEL:  0  ITERATION:  3  METRIC:  -0.20990756575673872
# LEVEL:  0  ITERATION:  4  METRIC:  -0.21198812178919912
# LEVEL:  0  ITERATION:  5  METRIC:  -0.21378254505095287
# LEVEL:  0  ITERATION:  6  METRIC:  -0.21459866407179895
# LEVEL:  0  ITERATION:  7  METRIC:  -0.21525785289440394
# LEVEL:  0  ITERATION:  8  METRIC:  -0.21565736543063435
# LEVEL:  0  ITERATION:  9  METRIC:  -0.21598935548137194
# LEVEL:  0  ITERATION:  10  METRIC:  -0.2166694152759981
# LEVEL:  0  ITERATION:  11  METRIC:  -0.218495206120719
# LEVEL:  0  ITERATION:  12  METRIC:  -0.22103416860256012
# LEVEL:  0  ITERATION:  13  METRIC:  -0.2234739184986888
# LEVEL:  0  ITERATION:  14  METRIC:  -0.2254618843682725
# LEVEL:  0  ITERATION:  15  METRIC:  -0.2269071986692003
# LEVEL:  0  ITERATION:  16  METRIC:  -0.2279146992295486
# LEVEL:  0  ITERATION:  17  METRIC:  -0.22875359945822538
# LEVEL:  0  ITERATION:  18  METRIC:  -0.22945071508631068
# LEVEL:  0  ITERATION:  19  METRIC:  -0.23017618952901572
# LEVEL:  0  ITERATION:  20  METRIC:  -0.2313581597581589
# LEVEL:  0  ITERATION:  21  METRIC:  -0.23299262120063102
# LEVEL:  0  ITERATION:  22  METRIC:  -0.2349119534280607
# LEVEL:  0  ITERATION:  23  METRIC:  -0.2368155853011098
# LEVEL:  0  ITERATION:  24  METRIC:  -0.23847203017043112
# LEVEL:  0  ITERATION:  25  METRIC:  -0.2400376861842967
# LEVEL:  0  ITERATION:  26  METRIC:  -0.24144505140026232
# LEVEL:  0  ITERATION:  27  METRIC:  -0.2425748007161232
# LEVEL:  0  ITERATION:  28  METRIC:  -0.24350546105470053
# LEVEL:  0  ITERATION:  29  METRIC:  -0.24444934345846162
# LEVEL:  0  ITERATION:  30  METRIC:  -0.2455811939074697
# LEVEL:  0  ITERATION:  31  METRIC:  -0.24681853733887438
# LEVEL:  0  ITERATION:  32  METRIC:  -0.2481084566810565
# LEVEL:  0  ITERATION:  33  METRIC:  -0.24961496606317704
# LEVEL:  0  ITERATION:  34  METRIC:  -0.25118748952689235
# LEVEL:  0  ITERATION:  35  METRIC:  -0.25264699148701714
# LEVEL:  0  ITERATION:  36  METRIC:  -0.25392677954150533
# LEVEL:  0  ITERATION:  37  METRIC:  -0.2549934343826343
# LEVEL:  0  ITERATION:  38  METRIC:  -0.2559474759356475
# LEVEL:  0  ITERATION:  39  METRIC:  -0.25689885485716063
# LEVEL:  0  ITERATION:  40  METRIC:  -0.2578702133369408
# LEVEL:  0  ITERATION:  41  METRIC:  -0.25900559797070294
# LEVEL:  0  ITERATION:  42  METRIC:  -0.26037070054048117
# LEVEL:  0  ITERATION:  43  METRIC:  -0.26178999747396897
# LEVEL:  0  ITERATION:  44  METRIC:  -0.2632408142194877
# LEVEL:  0  ITERATION:  45  METRIC:  -0.26468081443163055
# LEVEL:  0  ITERATION:  46  METRIC:  -0.2660421572550623
# LEVEL:  0  ITERATION:  47  METRIC:  -0.267336929922851
# LEVEL:  0  ITERATION:  48  METRIC:  -0.2686068130222419
# LEVEL:  0  ITERATION:  49  METRIC:  -0.26984099073559864
# LEVEL:  0  ITERATION:  50  METRIC:  -0.27117806644041015
# LEVEL:  0  ITERATION:  51  METRIC:  -0.27241601940261867
# LEVEL:  0  ITERATION:  52  METRIC:  -0.27349746637124295
# LEVEL:  0  ITERATION:  53  METRIC:  -0.2744426176123414
# LEVEL:  0  ITERATION:  54  METRIC:  -0.27527537645251493
# LEVEL:  0  ITERATION:  55  METRIC:  -0.27596277915192524
# LEVEL:  0  ITERATION:  56  METRIC:  -0.2764771712832117
# LEVEL:  0  ITERATION:  57  METRIC:  -0.27697166194046463
# LEVEL:  0  ITERATION:  58  METRIC:  -0.2774233539690918
# LEVEL:  0  ITERATION:  59  METRIC:  -0.2779093976144244
# LEVEL:  0  ITERATION:  60  METRIC:  -0.27837876036096704
# LEVEL:  0  ITERATION:  61  METRIC:  -0.27878191243021144
# LEVEL:  0  ITERATION:  62  METRIC:  -0.2791695414516115
# LEVEL:  0  ITERATION:  63  METRIC:  -0.27958957387901834
# LEVEL:  0  ITERATION:  64  METRIC:  -0.28006800849190244
# LEVEL:  0  ITERATION:  65  METRIC:  -0.28060393441973647
# LEVEL:  0  ITERATION:  66  METRIC:  -0.2811696298462939
# LEVEL:  0  ITERATION:  67  METRIC:  -0.2817029524249508
# LEVEL:  0  ITERATION:  68  METRIC:  -0.28228785284295643
# LEVEL:  0  ITERATION:  69  METRIC:  -0.28293867243895865
# LEVEL:  0  ITERATION:  70  METRIC:  -0.283386917796389
# LEVEL:  0  ITERATION:  71  METRIC:  -0.283676900421091
# LEVEL:  0  ITERATION:  72  METRIC:  -0.2838318701418627
# LEVEL:  0  ITERATION:  73  METRIC:  -0.2839186783604511
# LEVEL:  0  ITERATION:  74  METRIC:  -0.28400591802326863
# LEVEL:  0  ITERATION:  75  METRIC:  -0.2841137520752603
# LEVEL:  0  ITERATION:  76  METRIC:  -0.28425414164581175
# LEVEL:  0  ITERATION:  77  METRIC:  -0.2846178034750684
# LEVEL:  0  ITERATION:  78  METRIC:  -0.2851460796644896
# LEVEL:  0  ITERATION:  79  METRIC:  -0.28559779727721546
# LEVEL:  0  ITERATION:  80  METRIC:  -0.285979887323204
# LEVEL:  0  ITERATION:  81  METRIC:  -0.2863125629274057
# LEVEL:  0  ITERATION:  82  METRIC:  -0.28655649122589816
# LEVEL:  0  ITERATION:  83  METRIC:  -0.28672726283143846
# LEVEL:  0  ITERATION:  84  METRIC:  -0.28682429429456624
# LEVEL:  0  ITERATION:  85  METRIC:  -0.2869794886604282
# LEVEL:  0  ITERATION:  86  METRIC:  -0.2873854887345787
# LEVEL:  0  ITERATION:  87  METRIC:  -0.28770891983631225
# LEVEL:  0  ITERATION:  88  METRIC:  -0.287981042701408
# LEVEL:  0  ITERATION:  89  METRIC:  -0.2882237024302448
# LEVEL:  0  ITERATION:  90  METRIC:  -0.28842328582384763
# LEVEL:  0  ITERATION:  91  METRIC:  -0.2885476285006568
# LEVEL:  0  ITERATION:  92  METRIC:  -0.2886024185504683
# LEVEL:  0  ITERATION:  93  METRIC:  -0.2886806252727293
# LEVEL:  0  ITERATION:  94  METRIC:  -0.2891604739541105
# LEVEL:  0  ITERATION:  95  METRIC:  -0.28959216017336786
# LEVEL:  0  ITERATION:  96  METRIC:  -0.28995877104183604
# LEVEL:  0  ITERATION:  97  METRIC:  -0.2902393492336247
# LEVEL:  0  ITERATION:  98  METRIC:  -0.2904707014584399
# LEVEL:  0  ITERATION:  99  METRIC:  -0.2906619000810056
# LEVEL:  0  ITERATION:  100  METRIC:  -0.29078634730043196
# LEVEL:  0  ITERATION:  101  METRIC:  -0.2908789231664305
# LEVEL:  0  ITERATION:  102  METRIC:  -0.2913004279068376
# LEVEL:  0  ITERATION:  103  METRIC:  -0.29164798752844623
# LEVEL:  0  ITERATION:  104  METRIC:  -0.291962890323429
# LEVEL:  0  ITERATION:  105  METRIC:  -0.2922255232353335
# LEVEL:  0  ITERATION:  106  METRIC:  -0.29243309217010544
# LEVEL:  0  ITERATION:  107  METRIC:  -0.2926399820098786
# LEVEL:  0  ITERATION:  108  METRIC:  -0.29277754701109665
# LEVEL:  0  ITERATION:  109  METRIC:  -0.29289610295078466
# LEVEL:  0  ITERATION:  110  METRIC:  -0.2933530902409348
# LEVEL:  0  ITERATION:  111  METRIC:  -0.29373483626276153
# LEVEL:  0  ITERATION:  112  METRIC:  -0.29402617616284216
# LEVEL:  0  ITERATION:  113  METRIC:  -0.294228147663345
# LEVEL:  0  ITERATION:  114  METRIC:  -0.29437641819342447
# LEVEL:  0  ITERATION:  115  METRIC:  -0.2944786403274833
# LEVEL:  0  ITERATION:  116  METRIC:  -0.294563635068896
# LEVEL:  0  ITERATION:  117  METRIC:  -0.2946230864587242
# LEVEL:  0  ITERATION:  118  METRIC:  -0.29502250120494694
# LEVEL:  0  ITERATION:  119  METRIC:  -0.2953849908140019
# LEVEL:  0  ITERATION:  120  METRIC:  -0.2956825065441496
# LEVEL:  0  ITERATION:  121  METRIC:  -0.29592511680897854
# LEVEL:  0  ITERATION:  122  METRIC:  -0.2960819337612428
# LEVEL:  0  ITERATION:  123  METRIC:  -0.2961509033909563
# LEVEL:  0  ITERATION:  124  METRIC:  -0.2962249676451392
# LEVEL:  0  ITERATION:  125  METRIC:  -0.29625076551319657
# LEVEL:  0  ITERATION:  126  METRIC:  -0.29655059429357367
# LEVEL:  0  ITERATION:  127  METRIC:  -0.2968759665730333
# LEVEL:  0  ITERATION:  128  METRIC:  -0.2971329696309485
# LEVEL:  0  ITERATION:  129  METRIC:  -0.29732359984966034
# LEVEL:  0  ITERATION:  130  METRIC:  -0.2974383363370319
# LEVEL:  0  ITERATION:  131  METRIC:  -0.2974915614884975
# LEVEL:  0  ITERATION:  132  METRIC:  -0.2975193730258903
# LEVEL:  0  ITERATION:  133  METRIC:  -0.29758758436097876
# LEVEL:  0  ITERATION:  134  METRIC:  -0.2978875179146292
# LEVEL:  0  ITERATION:  135  METRIC:  -0.29831667129562456
# LEVEL:  0  ITERATION:  136  METRIC:  -0.29866877907977
# LEVEL:  0  ITERATION:  137  METRIC:  -0.29894140551131726
# LEVEL:  0  ITERATION:  138  METRIC:  -0.2991331447677418
# LEVEL:  0  ITERATION:  139  METRIC:  -0.2992570602665293
# LEVEL:  0  ITERATION:  140  METRIC:  -0.29932048929145216
# LEVEL:  0  ITERATION:  141  METRIC:  -0.2993687815847233
# LEVEL:  0  ITERATION:  142  METRIC:  -0.2995178854187056
# LEVEL:  0  ITERATION:  143  METRIC:  -0.29987329295113363
# LEVEL:  0  ITERATION:  144  METRIC:  -0.3001679326819445
# LEVEL:  0  ITERATION:  145  METRIC:  -0.3004382563780014
# LEVEL:  0  ITERATION:  146  METRIC:  -0.30064558530358004
# LEVEL:  0  ITERATION:  147  METRIC:  -0.30076365484080325
# LEVEL:  0  ITERATION:  148  METRIC:  -0.30080341458582177
# LEVEL:  0  ITERATION:  149  METRIC:  -0.3008193116929662
# LEVEL:  0  ITERATION:  150  METRIC:  -0.3008768208347575
# LEVEL:  0  ITERATION:  151  METRIC:  -0.3010908210668736
# LEVEL:  0  ITERATION:  152  METRIC:  -0.3013146796661016
# LEVEL:  0  ITERATION:  153  METRIC:  -0.3014804586759444
# LEVEL:  0  ITERATION:  154  METRIC:  -0.3015790671685987
# LEVEL:  0  ITERATION:  155  METRIC:  -0.30163576524527136
# LEVEL:  0  ITERATION:  156  METRIC:  -0.30164366576599877
# LEVEL:  0  ITERATION:  157  METRIC:  -0.30163373618482026
# LEVEL:  0  ITERATION:  158  METRIC:  -0.30164622845964345
# LEVEL:  0  ITERATION:  159  METRIC:  -0.30174406413975974
# LEVEL:  0  ITERATION:  160  METRIC:  -0.30193811476837634
# LEVEL:  0  ITERATION:  161  METRIC:  -0.3022872534597177
# LEVEL:  0  ITERATION:  162  METRIC:  -0.30257488762646134
# LEVEL:  0  ITERATION:  163  METRIC:  -0.30275336632423977
# LEVEL:  0  ITERATION:  164  METRIC:  -0.302896432679731
# LEVEL:  0  ITERATION:  165  METRIC:  -0.30309263827496763
# LEVEL:  0  ITERATION:  166  METRIC:  -0.30320971255271706
# LEVEL:  0  ITERATION:  167  METRIC:  -0.30338795671832686
# Registration succeeded
# CPU times: user 27min 18s, sys: 33.5 s, total: 27min 52s
# Wall time: 4min 53s

# %%
# %%time



steps = [('ransac', ransac_kwargs,),
         ('affine', affine_kwargs,),]

# align
affine1 = alignment_pipeline(
    fix, mov1,
    fix_spacing_s4,
    mov_spacing_s4,
    steps,
    # fix_mask=fix_mask,
    # mov_mask=mov_mask,
)

# apply affine only
affine_aligned1 = apply_transform(
    fix, mov1,
    fix_spacing_s4, mov_spacing_s4,
    transform_list=[affine1,],
)

# write results
np.savetxt(outdir+'/affine-rev-v1.mat', affine1)
# nrrd.write(outdir+'/affine.nrrd', affine_aligned.transpose(2,1,0), compression_level=2)
tifffile.imwrite(outdir+'/affine-rev-v1.tiff', affine_aligned1.transpose([2,1,0]))

# # load precomputed results
# affine = np.loadtxt(outdir+'/affine.mat')
# Out:
# computing fixed spots
# found 22 fixed spots
# insufficient fixed spots found, returning default
# LEVEL:  0  ITERATION:  0  METRIC:  -0.03170105506137656
# LEVEL:  0  ITERATION:  1  METRIC:  -0.03185443186591749
# LEVEL:  0  ITERATION:  2  METRIC:  -0.03199816080102511
# LEVEL:  0  ITERATION:  3  METRIC:  -0.0321360072627238
# LEVEL:  0  ITERATION:  4  METRIC:  -0.032284684999454874
# LEVEL:  0  ITERATION:  5  METRIC:  -0.032449955140930076
# LEVEL:  0  ITERATION:  6  METRIC:  -0.03261588258298739
# LEVEL:  0  ITERATION:  7  METRIC:  -0.03277660999663365
# LEVEL:  0  ITERATION:  8  METRIC:  -0.032930276185227536
# LEVEL:  0  ITERATION:  9  METRIC:  -0.03307363702157451
# LEVEL:  0  ITERATION:  10  METRIC:  -0.03320939425427208
# LEVEL:  0  ITERATION:  11  METRIC:  -0.03333818594896499
# LEVEL:  0  ITERATION:  12  METRIC:  -0.03347459456640145
# LEVEL:  0  ITERATION:  13  METRIC:  -0.033628795367170256
# LEVEL:  0  ITERATION:  14  METRIC:  -0.033786311490936416
# LEVEL:  0  ITERATION:  15  METRIC:  -0.03394875721251757
# LEVEL:  0  ITERATION:  16  METRIC:  -0.03409950277512366
# LEVEL:  0  ITERATION:  17  METRIC:  -0.034242770269546016
# LEVEL:  0  ITERATION:  18  METRIC:  -0.03437631321730462
# LEVEL:  0  ITERATION:  19  METRIC:  -0.03450389867043584
# LEVEL:  0  ITERATION:  20  METRIC:  -0.03463354349997452
# LEVEL:  0  ITERATION:  21  METRIC:  -0.03478520334612152
# LEVEL:  0  ITERATION:  22  METRIC:  -0.034935988967543165
# LEVEL:  0  ITERATION:  23  METRIC:  -0.0350958128651544
# LEVEL:  0  ITERATION:  24  METRIC:  -0.03524866581557366
# LEVEL:  0  ITERATION:  25  METRIC:  -0.035393812324056535
# LEVEL:  0  ITERATION:  26  METRIC:  -0.035533226851051904
# LEVEL:  0  ITERATION:  27  METRIC:  -0.03566512359073598
# LEVEL:  0  ITERATION:  28  METRIC:  -0.035794017169987445
# LEVEL:  0  ITERATION:  29  METRIC:  -0.0359415988497414
# LEVEL:  0  ITERATION:  30  METRIC:  -0.036093443795325086
# LEVEL:  0  ITERATION:  31  METRIC:  -0.03623790292008446
# LEVEL:  0  ITERATION:  32  METRIC:  -0.03638207726602764
# LEVEL:  0  ITERATION:  33  METRIC:  -0.03652003190833103
# LEVEL:  0  ITERATION:  34  METRIC:  -0.036647212454840296
# LEVEL:  0  ITERATION:  35  METRIC:  -0.036764036503580344
# LEVEL:  0  ITERATION:  36  METRIC:  -0.03687412282436872
# LEVEL:  0  ITERATION:  37  METRIC:  -0.036997137874730114
# LEVEL:  0  ITERATION:  38  METRIC:  -0.03713354577850029
# LEVEL:  0  ITERATION:  39  METRIC:  -0.03726066164300156
# LEVEL:  0  ITERATION:  40  METRIC:  -0.03738623141706018
# LEVEL:  0  ITERATION:  41  METRIC:  -0.037508175589491266
# LEVEL:  0  ITERATION:  42  METRIC:  -0.03761808300211862
# LEVEL:  0  ITERATION:  43  METRIC:  -0.037718736111426496
# LEVEL:  0  ITERATION:  44  METRIC:  -0.037811916060820586
# LEVEL:  0  ITERATION:  45  METRIC:  -0.03790704827050534
# LEVEL:  0  ITERATION:  46  METRIC:  -0.03802401464863198
# LEVEL:  0  ITERATION:  47  METRIC:  -0.038136684910444016
# LEVEL:  0  ITERATION:  48  METRIC:  -0.03823982477507807
# LEVEL:  0  ITERATION:  49  METRIC:  -0.0383418921112045
# LEVEL:  0  ITERATION:  50  METRIC:  -0.03843931631024761
# LEVEL:  0  ITERATION:  51  METRIC:  -0.03853101462182832
# LEVEL:  0  ITERATION:  52  METRIC:  -0.03861316519418846
# LEVEL:  0  ITERATION:  53  METRIC:  -0.03868920953866381
# LEVEL:  0  ITERATION:  54  METRIC:  -0.03878173595078482
# LEVEL:  0  ITERATION:  55  METRIC:  -0.03888217389287792
# LEVEL:  0  ITERATION:  56  METRIC:  -0.03897567007872723
# LEVEL:  0  ITERATION:  57  METRIC:  -0.039061581568325655
# LEVEL:  0  ITERATION:  58  METRIC:  -0.03915075574135724
# LEVEL:  0  ITERATION:  59  METRIC:  -0.039241880487762414
# LEVEL:  0  ITERATION:  60  METRIC:  -0.03932239509265549
# LEVEL:  0  ITERATION:  61  METRIC:  -0.03939529913111194
# LEVEL:  0  ITERATION:  62  METRIC:  -0.039467850986071334
# LEVEL:  0  ITERATION:  63  METRIC:  -0.03955887944203918
# LEVEL:  0  ITERATION:  64  METRIC:  -0.039651378678055356
# LEVEL:  0  ITERATION:  65  METRIC:  -0.039736436185716976
# LEVEL:  0  ITERATION:  66  METRIC:  -0.03981654189454567
# LEVEL:  0  ITERATION:  67  METRIC:  -0.039898547724846384
# LEVEL:  0  ITERATION:  68  METRIC:  -0.03998595122174229
# LEVEL:  0  ITERATION:  69  METRIC:  -0.04006590724897762
# LEVEL:  0  ITERATION:  70  METRIC:  -0.04013933231430395
# LEVEL:  0  ITERATION:  71  METRIC:  -0.04020810126576282
# LEVEL:  0  ITERATION:  72  METRIC:  -0.040298691753365264
# LEVEL:  0  ITERATION:  73  METRIC:  -0.040388386368979554
# LEVEL:  0  ITERATION:  74  METRIC:  -0.04047034931542664
# LEVEL:  0  ITERATION:  75  METRIC:  -0.040550580726312464
# LEVEL:  0  ITERATION:  76  METRIC:  -0.04062502229224465
# LEVEL:  0  ITERATION:  77  METRIC:  -0.04070033441574983
# LEVEL:  0  ITERATION:  78  METRIC:  -0.04078025250960347
# LEVEL:  0  ITERATION:  79  METRIC:  -0.040849738865876256
# LEVEL:  0  ITERATION:  80  METRIC:  -0.04091232268072411
# LEVEL:  0  ITERATION:  81  METRIC:  -0.04099923419033569
# LEVEL:  0  ITERATION:  82  METRIC:  -0.041088256148783205
# LEVEL:  0  ITERATION:  83  METRIC:  -0.041172346707815374
# LEVEL:  0  ITERATION:  84  METRIC:  -0.04124833144420832
# LEVEL:  0  ITERATION:  85  METRIC:  -0.04131461879074681
# LEVEL:  0  ITERATION:  86  METRIC:  -0.04137627573676152
# LEVEL:  0  ITERATION:  87  METRIC:  -0.04144630444324121
# LEVEL:  0  ITERATION:  88  METRIC:  -0.04150941743800275
# LEVEL:  0  ITERATION:  89  METRIC:  -0.041571435489837306
# LEVEL:  0  ITERATION:  90  METRIC:  -0.04164836118590953
# LEVEL:  0  ITERATION:  91  METRIC:  -0.041729899473944475
# LEVEL:  0  ITERATION:  92  METRIC:  -0.041807597057565205
# LEVEL:  0  ITERATION:  93  METRIC:  -0.041876769613004676
# LEVEL:  0  ITERATION:  94  METRIC:  -0.041937207668586635
# LEVEL:  0  ITERATION:  95  METRIC:  -0.041997682159897645
# LEVEL:  0  ITERATION:  96  METRIC:  -0.04205401896971345
# LEVEL:  0  ITERATION:  97  METRIC:  -0.04211245770072567
# LEVEL:  0  ITERATION:  98  METRIC:  -0.042161401826684854
# LEVEL:  0  ITERATION:  99  METRIC:  -0.042214511009741516
# LEVEL:  0  ITERATION:  100  METRIC:  -0.04228455729417928
# LEVEL:  0  ITERATION:  101  METRIC:  -0.042352354747353785
# LEVEL:  0  ITERATION:  102  METRIC:  -0.04241016091644599
# LEVEL:  0  ITERATION:  103  METRIC:  -0.04246602488079263
# LEVEL:  0  ITERATION:  104  METRIC:  -0.04252312020649146
# LEVEL:  0  ITERATION:  105  METRIC:  -0.04257511460424246
# LEVEL:  0  ITERATION:  106  METRIC:  -0.04262389761478562
# LEVEL:  0  ITERATION:  107  METRIC:  -0.042671616988938635
# LEVEL:  0  ITERATION:  108  METRIC:  -0.042715983853746926
# LEVEL:  0  ITERATION:  109  METRIC:  -0.04278156441960856
# LEVEL:  0  ITERATION:  110  METRIC:  -0.04285413878467518
# LEVEL:  0  ITERATION:  111  METRIC:  -0.042915654338956166
# LEVEL:  0  ITERATION:  112  METRIC:  -0.042973743443201776
# LEVEL:  0  ITERATION:  113  METRIC:  -0.043029954756502446
# LEVEL:  0  ITERATION:  114  METRIC:  -0.04308069158619926
# LEVEL:  0  ITERATION:  115  METRIC:  -0.04312017580009512
# LEVEL:  0  ITERATION:  116  METRIC:  -0.04315403988983626
# LEVEL:  0  ITERATION:  117  METRIC:  -0.04319020301784548
# LEVEL:  0  ITERATION:  118  METRIC:  -0.04323308369649481
# LEVEL:  0  ITERATION:  119  METRIC:  -0.04328727299543635
# LEVEL:  0  ITERATION:  120  METRIC:  -0.04334530395484397
# LEVEL:  0  ITERATION:  121  METRIC:  -0.04339878299025878
# LEVEL:  0  ITERATION:  122  METRIC:  -0.04344709839085354
# LEVEL:  0  ITERATION:  123  METRIC:  -0.04348697367829167
# LEVEL:  0  ITERATION:  124  METRIC:  -0.04351535234204793
# LEVEL:  0  ITERATION:  125  METRIC:  -0.04353134257623979
# LEVEL:  0  ITERATION:  126  METRIC:  -0.043541130619539736
# LEVEL:  0  ITERATION:  127  METRIC:  -0.04354746258219048
# LEVEL:  0  ITERATION:  128  METRIC:  -0.04355764699444465
# LEVEL:  0  ITERATION:  129  METRIC:  -0.043580920091810076
# LEVEL:  0  ITERATION:  130  METRIC:  -0.04361396621466911
# LEVEL:  0  ITERATION:  131  METRIC:  -0.04365100957188123
# LEVEL:  0  ITERATION:  132  METRIC:  -0.04368642272783692
# LEVEL:  0  ITERATION:  133  METRIC:  -0.04371961034142117
# LEVEL:  0  ITERATION:  134  METRIC:  -0.0437486493171174
# LEVEL:  0  ITERATION:  135  METRIC:  -0.04377515023332756
# LEVEL:  0  ITERATION:  136  METRIC:  -0.0438043566133437
# LEVEL:  0  ITERATION:  137  METRIC:  -0.04382955527880635
# LEVEL:  0  ITERATION:  138  METRIC:  -0.04387009591476923
# LEVEL:  0  ITERATION:  139  METRIC:  -0.04393572655069231
# LEVEL:  0  ITERATION:  140  METRIC:  -0.0440238621194722
# LEVEL:  0  ITERATION:  141  METRIC:  -0.0441123293090357
# LEVEL:  0  ITERATION:  142  METRIC:  -0.04419172106124466
# LEVEL:  0  ITERATION:  143  METRIC:  -0.04425599730088154
# LEVEL:  0  ITERATION:  144  METRIC:  -0.044306687505804826
# LEVEL:  0  ITERATION:  145  METRIC:  -0.044348435726590224
# LEVEL:  0  ITERATION:  146  METRIC:  -0.04438035660729751
# LEVEL:  0  ITERATION:  147  METRIC:  -0.04439962508411844
# LEVEL:  0  ITERATION:  148  METRIC:  -0.04441066022896928
# LEVEL:  0  ITERATION:  149  METRIC:  -0.04442974945940884
# LEVEL:  0  ITERATION:  150  METRIC:  -0.0444639078790332
# LEVEL:  0  ITERATION:  151  METRIC:  -0.044507176282096675
# LEVEL:  0  ITERATION:  152  METRIC:  -0.04454537881103846
# LEVEL:  0  ITERATION:  153  METRIC:  -0.04458071732982185
# LEVEL:  0  ITERATION:  154  METRIC:  -0.04461058507620883
# LEVEL:  0  ITERATION:  155  METRIC:  -0.04462954180738937
# LEVEL:  0  ITERATION:  156  METRIC:  -0.044649001803802116
# LEVEL:  0  ITERATION:  157  METRIC:  -0.04468947705768697
# LEVEL:  0  ITERATION:  158  METRIC:  -0.04473392054162432
# LEVEL:  0  ITERATION:  159  METRIC:  -0.04477325959122923
# LEVEL:  0  ITERATION:  160  METRIC:  -0.04482994730738683
# LEVEL:  0  ITERATION:  161  METRIC:  -0.044901968737390066
# LEVEL:  0  ITERATION:  162  METRIC:  -0.044999852213523636
# LEVEL:  0  ITERATION:  163  METRIC:  -0.045093820703512345
# LEVEL:  0  ITERATION:  164  METRIC:  -0.04516787924312818
# LEVEL:  0  ITERATION:  165  METRIC:  -0.04522203755949371
# LEVEL:  0  ITERATION:  166  METRIC:  -0.04526262531196899
# LEVEL:  0  ITERATION:  167  METRIC:  -0.0452837799841203
# LEVEL:  0  ITERATION:  168  METRIC:  -0.0452829927837087
# LEVEL:  0  ITERATION:  169  METRIC:  -0.045269081759108425
# LEVEL:  0  ITERATION:  170  METRIC:  -0.04525761151806991
# LEVEL:  0  ITERATION:  171  METRIC:  -0.04523730140156141
# LEVEL:  0  ITERATION:  172  METRIC:  -0.04523501853257351
# LEVEL:  0  ITERATION:  173  METRIC:  -0.04526704133796373
# LEVEL:  0  ITERATION:  174  METRIC:  -0.04530824934417526
# LEVEL:  0  ITERATION:  175  METRIC:  -0.045359588037175685
# LEVEL:  0  ITERATION:  176  METRIC:  -0.04540443324414469
# LEVEL:  0  ITERATION:  177  METRIC:  -0.045436876320898434
# LEVEL:  0  ITERATION:  178  METRIC:  -0.04545691899647637
# LEVEL:  0  ITERATION:  179  METRIC:  -0.04546464904831591
# LEVEL:  0  ITERATION:  180  METRIC:  -0.04546436646732871
# LEVEL:  0  ITERATION:  181  METRIC:  -0.04547467202640043
# LEVEL:  0  ITERATION:  182  METRIC:  -0.04550898421015516
# LEVEL:  0  ITERATION:  183  METRIC:  -0.045561798088379284
# LEVEL:  0  ITERATION:  184  METRIC:  -0.04563451143097877
# LEVEL:  0  ITERATION:  185  METRIC:  -0.04572474789043181
# LEVEL:  0  ITERATION:  186  METRIC:  -0.045820986521543546
# LEVEL:  0  ITERATION:  187  METRIC:  -0.04591153759803299
# LEVEL:  0  ITERATION:  188  METRIC:  -0.04599518148128065
# LEVEL:  0  ITERATION:  189  METRIC:  -0.04604849005725833
# LEVEL:  0  ITERATION:  190  METRIC:  -0.046069165188672316
# LEVEL:  0  ITERATION:  191  METRIC:  -0.04597166643643388
# LEVEL:  0  ITERATION:  192  METRIC:  -0.045784655973601984
# LEVEL:  0  ITERATION:  193  METRIC:  -0.04553352224317303
# LEVEL:  0  ITERATION:  194  METRIC:  -0.045480547920714855
# LEVEL:  0  ITERATION:  195  METRIC:  -0.04553976160397798
# LEVEL:  0  ITERATION:  196  METRIC:  -0.04561165545901013
# LEVEL:  0  ITERATION:  197  METRIC:  -0.04568134139388655
# LEVEL:  0  ITERATION:  198  METRIC:  -0.04574301133127727
# LEVEL:  0  ITERATION:  199  METRIC:  -0.04579453827673983
# LEVEL:  0  ITERATION:  200  METRIC:  -0.04584486499952699
# LEVEL:  0  ITERATION:  201  METRIC:  -0.04588985316142613
# LEVEL:  0  ITERATION:  202  METRIC:  -0.04592667474542539
# LEVEL:  0  ITERATION:  203  METRIC:  -0.04595233573264621
# LEVEL:  0  ITERATION:  204  METRIC:  -0.04597248973751136
# LEVEL:  0  ITERATION:  205  METRIC:  -0.046002234901424036
# LEVEL:  0  ITERATION:  206  METRIC:  -0.04604801789530476
# LEVEL:  0  ITERATION:  207  METRIC:  -0.04609869175657544
# LEVEL:  0  ITERATION:  208  METRIC:  -0.04615007589472064
# LEVEL:  0  ITERATION:  209  METRIC:  -0.04619881708165443
# LEVEL:  0  ITERATION:  210  METRIC:  -0.04624554114730029
# LEVEL:  0  ITERATION:  211  METRIC:  -0.04629435695452942
# LEVEL:  0  ITERATION:  212  METRIC:  -0.04634172848582118
# LEVEL:  0  ITERATION:  213  METRIC:  -0.04637814718079507
# LEVEL:  0  ITERATION:  214  METRIC:  -0.04641111264240011
# LEVEL:  0  ITERATION:  215  METRIC:  -0.04644559025859351
# LEVEL:  0  ITERATION:  216  METRIC:  -0.046496761923826464
# LEVEL:  0  ITERATION:  217  METRIC:  -0.04655805813197804
# LEVEL:  0  ITERATION:  218  METRIC:  -0.04662570620175499
# LEVEL:  0  ITERATION:  219  METRIC:  -0.046696077034042355
# LEVEL:  0  ITERATION:  220  METRIC:  -0.04676542986657854
# LEVEL:  0  ITERATION:  221  METRIC:  -0.04683549854134363
# LEVEL:  0  ITERATION:  222  METRIC:  -0.046898291617576436
# LEVEL:  0  ITERATION:  223  METRIC:  -0.0469548098771435
# LEVEL:  0  ITERATION:  224  METRIC:  -0.04701321098308822
# LEVEL:  0  ITERATION:  225  METRIC:  -0.047065590411405255
# LEVEL:  0  ITERATION:  226  METRIC:  -0.04712017160514858
# LEVEL:  0  ITERATION:  227  METRIC:  -0.047178893300724785
# LEVEL:  0  ITERATION:  228  METRIC:  -0.04723626074958809
# LEVEL:  0  ITERATION:  229  METRIC:  -0.0472910103094042
# LEVEL:  0  ITERATION:  230  METRIC:  -0.04733931519597744
# LEVEL:  0  ITERATION:  231  METRIC:  -0.04737723941649607
# LEVEL:  0  ITERATION:  232  METRIC:  -0.04740317993328716
# LEVEL:  0  ITERATION:  233  METRIC:  -0.04741510994471792
# LEVEL:  0  ITERATION:  234  METRIC:  -0.04741181249580769
# LEVEL:  0  ITERATION:  235  METRIC:  -0.04739837945921055
# LEVEL:  0  ITERATION:  236  METRIC:  -0.047391510729477525
# LEVEL:  0  ITERATION:  237  METRIC:  -0.04739765774046252
# LEVEL:  0  ITERATION:  238  METRIC:  -0.04741077852953647
# LEVEL:  0  ITERATION:  239  METRIC:  -0.04743313221613608
# LEVEL:  0  ITERATION:  240  METRIC:  -0.047452921123340285
# LEVEL:  0  ITERATION:  241  METRIC:  -0.047471157468245984
# LEVEL:  0  ITERATION:  242  METRIC:  -0.047487510923592366
# LEVEL:  0  ITERATION:  243  METRIC:  -0.047503024167162615
# LEVEL:  0  ITERATION:  244  METRIC:  -0.04750408656859661
# LEVEL:  0  ITERATION:  245  METRIC:  -0.047490084512285514
# LEVEL:  0  ITERATION:  246  METRIC:  -0.04747527639202987
# LEVEL:  0  ITERATION:  247  METRIC:  -0.047470154158526234
# LEVEL:  0  ITERATION:  248  METRIC:  -0.04748711907667859
# LEVEL:  0  ITERATION:  249  METRIC:  -0.04751026303047614
# LEVEL:  0  ITERATION:  250  METRIC:  -0.04752323577557177
# LEVEL:  0  ITERATION:  251  METRIC:  -0.04752693004140095
# LEVEL:  0  ITERATION:  252  METRIC:  -0.047522223366777534
# LEVEL:  0  ITERATION:  253  METRIC:  -0.04750015399739015
# LEVEL:  0  ITERATION:  254  METRIC:  -0.04748075027589411
# LEVEL:  0  ITERATION:  255  METRIC:  -0.04745470622574129
# LEVEL:  0  ITERATION:  256  METRIC:  -0.04742470062901747
# LEVEL:  0  ITERATION:  257  METRIC:  -0.04739824107353219
# LEVEL:  0  ITERATION:  258  METRIC:  -0.04736577301791665
# LEVEL:  0  ITERATION:  259  METRIC:  -0.04731842551674599
# LEVEL:  0  ITERATION:  260  METRIC:  -0.047258783208229176
# LEVEL:  0  ITERATION:  261  METRIC:  -0.04719389473244048
# LEVEL:  0  ITERATION:  262  METRIC:  -0.04711814850637132
# LEVEL:  0  ITERATION:  263  METRIC:  -0.0470601337463771
# LEVEL:  0  ITERATION:  264  METRIC:  -0.04701234364042035
# LEVEL:  0  ITERATION:  265  METRIC:  -0.04696765740567093
# LEVEL:  0  ITERATION:  266  METRIC:  -0.04693702932246753
# LEVEL:  0  ITERATION:  267  METRIC:  -0.04692712305686697
# LEVEL:  0  ITERATION:  268  METRIC:  -0.046932573223638786
# LEVEL:  0  ITERATION:  269  METRIC:  -0.0469229836635765
# LEVEL:  0  ITERATION:  270  METRIC:  -0.04690095863921142
# LEVEL:  0  ITERATION:  271  METRIC:  -0.04687540086150958
# LEVEL:  0  ITERATION:  272  METRIC:  -0.04684084522655771
# LEVEL:  0  ITERATION:  273  METRIC:  -0.04679259037829618
# LEVEL:  0  ITERATION:  274  METRIC:  -0.046733342848796135
# LEVEL:  0  ITERATION:  275  METRIC:  -0.04667224892310821
# LEVEL:  0  ITERATION:  276  METRIC:  -0.04662656790761576
# LEVEL:  0  ITERATION:  277  METRIC:  -0.04657845777800478
# LEVEL:  0  ITERATION:  278  METRIC:  -0.04654020258765755
# LEVEL:  0  ITERATION:  279  METRIC:  -0.04649428873644076
# LEVEL:  0  ITERATION:  280  METRIC:  -0.04644268028141365
# LEVEL:  0  ITERATION:  281  METRIC:  -0.04638593932275222
# LEVEL:  0  ITERATION:  282  METRIC:  -0.046325046246227804
# LEVEL:  0  ITERATION:  283  METRIC:  -0.046253967424725366
# LEVEL:  0  ITERATION:  284  METRIC:  -0.04618326341511075
# LEVEL:  0  ITERATION:  285  METRIC:  -0.046117324495444985
# LEVEL:  0  ITERATION:  286  METRIC:  -0.04605143927071173
# LEVEL:  0  ITERATION:  287  METRIC:  -0.045990125719417345
# LEVEL:  0  ITERATION:  288  METRIC:  -0.045960976718914553
# LEVEL:  0  ITERATION:  289  METRIC:  -0.045952898724544465
# LEVEL:  0  ITERATION:  290  METRIC:  -0.0459386224454655
# LEVEL:  0  ITERATION:  291  METRIC:  -0.04591130529169855
# LEVEL:  0  ITERATION:  292  METRIC:  -0.04587903682257644
# LEVEL:  0  ITERATION:  293  METRIC:  -0.04584929538847492
# LEVEL:  0  ITERATION:  294  METRIC:  -0.04581685271176404
# LEVEL:  0  ITERATION:  295  METRIC:  -0.04577858590948648
# LEVEL:  0  ITERATION:  296  METRIC:  -0.0457335037222758
# LEVEL:  0  ITERATION:  297  METRIC:  -0.04569744914052618
# LEVEL:  0  ITERATION:  298  METRIC:  -0.045670569696442724
# LEVEL:  0  ITERATION:  299  METRIC:  -0.0456405730292563
# LEVEL:  0  ITERATION:  300  METRIC:  -0.045597990901139224
# LEVEL:  0  ITERATION:  301  METRIC:  -0.04554407913967106
# LEVEL:  0  ITERATION:  302  METRIC:  -0.045494265196344655
# LEVEL:  0  ITERATION:  303  METRIC:  -0.045457868970018654
# LEVEL:  0  ITERATION:  304  METRIC:  -0.04542332961481245
# LEVEL:  0  ITERATION:  305  METRIC:  -0.04538458553759124
# LEVEL:  0  ITERATION:  306  METRIC:  -0.045354235912912336
# LEVEL:  0  ITERATION:  307  METRIC:  -0.045337344063405546
# LEVEL:  0  ITERATION:  308  METRIC:  -0.04531638646445765
# LEVEL:  0  ITERATION:  309  METRIC:  -0.04528853081535641
# LEVEL:  0  ITERATION:  310  METRIC:  -0.04525223198855106
# LEVEL:  0  ITERATION:  311  METRIC:  -0.045203772947989794
# LEVEL:  0  ITERATION:  312  METRIC:  -0.045151022622269034
# LEVEL:  0  ITERATION:  313  METRIC:  -0.045102358530890875
# LEVEL:  0  ITERATION:  314  METRIC:  -0.045052029627093905
# LEVEL:  0  ITERATION:  315  METRIC:  -0.045004269025175486
# LEVEL:  0  ITERATION:  316  METRIC:  -0.04496896139823659
# LEVEL:  0  ITERATION:  317  METRIC:  -0.04493695173612191
# LEVEL:  0  ITERATION:  318  METRIC:  -0.04489959470255859
# LEVEL:  0  ITERATION:  319  METRIC:  -0.04485453973129961
# LEVEL:  0  ITERATION:  320  METRIC:  -0.04481210179185287
# LEVEL:  0  ITERATION:  321  METRIC:  -0.04477448193548226
# LEVEL:  0  ITERATION:  322  METRIC:  -0.04473628311610447
# LEVEL:  0  ITERATION:  323  METRIC:  -0.04468933825234793
# LEVEL:  0  ITERATION:  324  METRIC:  -0.044638707051912675
# LEVEL:  0  ITERATION:  325  METRIC:  -0.04459875628129839
# LEVEL:  0  ITERATION:  326  METRIC:  -0.04456894878064863
# LEVEL:  0  ITERATION:  327  METRIC:  -0.04453790788702538
# LEVEL:  0  ITERATION:  328  METRIC:  -0.044493533150091615
# LEVEL:  0  ITERATION:  329  METRIC:  -0.04443991409158829
# LEVEL:  0  ITERATION:  330  METRIC:  -0.044376409559482785
# LEVEL:  0  ITERATION:  331  METRIC:  -0.0443016526638175
# LEVEL:  0  ITERATION:  332  METRIC:  -0.0442244574372825
# LEVEL:  0  ITERATION:  333  METRIC:  -0.0441503521045888
# LEVEL:  0  ITERATION:  334  METRIC:  -0.04408076620831358
# LEVEL:  0  ITERATION:  335  METRIC:  -0.04402476392559625
# LEVEL:  0  ITERATION:  336  METRIC:  -0.043983754495921755
# LEVEL:  0  ITERATION:  337  METRIC:  -0.043952758222603465
# LEVEL:  0  ITERATION:  338  METRIC:  -0.04391927350988086
# LEVEL:  0  ITERATION:  339  METRIC:  -0.043872279561382184
# LEVEL:  0  ITERATION:  340  METRIC:  -0.0438164166764024
# LEVEL:  0  ITERATION:  341  METRIC:  -0.04376072080811096
# LEVEL:  0  ITERATION:  342  METRIC:  -0.04369781662618706
# LEVEL:  0  ITERATION:  343  METRIC:  -0.04362722879692687
# LEVEL:  0  ITERATION:  344  METRIC:  -0.04356478025079971
# LEVEL:  0  ITERATION:  345  METRIC:  -0.0435202577295801
# LEVEL:  0  ITERATION:  346  METRIC:  -0.04348222830033125
# LEVEL:  0  ITERATION:  347  METRIC:  -0.043440722862156264
# LEVEL:  0  ITERATION:  348  METRIC:  -0.04339174185854735
# LEVEL:  0  ITERATION:  349  METRIC:  -0.04333660292226448
# LEVEL:  0  ITERATION:  350  METRIC:  -0.04327909910710423
# LEVEL:  0  ITERATION:  351  METRIC:  -0.04321494742761865
# LEVEL:  0  ITERATION:  352  METRIC:  -0.043143588799110184
# LEVEL:  0  ITERATION:  353  METRIC:  -0.043070720901271245
# LEVEL:  0  ITERATION:  354  METRIC:  -0.04301203135654824
# LEVEL:  0  ITERATION:  355  METRIC:  -0.042970647182997174
# LEVEL:  0  ITERATION:  356  METRIC:  -0.04293583045692003
# LEVEL:  0  ITERATION:  357  METRIC:  -0.0428977150970301
# LEVEL:  0  ITERATION:  358  METRIC:  -0.04285577302604454
# LEVEL:  0  ITERATION:  359  METRIC:  -0.04281127542600151
# LEVEL:  0  ITERATION:  360  METRIC:  -0.0427588325279287
# LEVEL:  0  ITERATION:  361  METRIC:  -0.0426943973847838
# LEVEL:  0  ITERATION:  362  METRIC:  -0.04261999596941525
# LEVEL:  0  ITERATION:  363  METRIC:  -0.0425378760074918
# LEVEL:  0  ITERATION:  364  METRIC:  -0.04245408889306945
# LEVEL:  0  ITERATION:  365  METRIC:  -0.04237564050536112
# LEVEL:  0  ITERATION:  366  METRIC:  -0.04229976370174421
# LEVEL:  0  ITERATION:  367  METRIC:  -0.042224582123742395
# LEVEL:  0  ITERATION:  368  METRIC:  -0.042153524421462585
# LEVEL:  0  ITERATION:  369  METRIC:  -0.042085116260732476
# LEVEL:  0  ITERATION:  370  METRIC:  -0.04200690176277108
# LEVEL:  0  ITERATION:  371  METRIC:  -0.04191201447814602
# LEVEL:  0  ITERATION:  372  METRIC:  -0.04179916484822439
# LEVEL:  0  ITERATION:  373  METRIC:  -0.041671521362039055
# LEVEL:  0  ITERATION:  374  METRIC:  -0.041533931183903174
# LEVEL:  0  ITERATION:  375  METRIC:  -0.04138882288907651
# Registration succeeded
# CPU times: user 1h 3min 6s, sys: 28 s, total: 1h 3min 34s
# Wall time: 7min 59s

# %% [markdown]
# ### local

# %%
from bigstream.piecewise_align import distributed_piecewise_alignment_pipeline
from bigstream.transform import apply_transform

import importlib
import bigstream
import bigstream.piecewise_align
importlib.reload(bigstream.piecewise_align)
# Out:
# <module 'bigstream.piecewise_align' from '/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/bigstream/piecewise_align.py'>

# %%
# %%time

# get global alignment channels
fix = fix_zarr['/c3/s3'][...]
mov = mov_zarr['/c3/s3'][...][:, ::-1, ::-1]  # moving image data is 180 degrees rotates about z axis

# define alignment steps
ransac_kwargs = {
    'blob_sizes':[4, 16],
    'cc_radius':16,
    'match_threshold':0.4,
    'nspots':4000,
}

affine_kwargs = {
    'alignment_spacing':2.0,
    'shrink_factors':(2,),
    'smooth_sigmas':(4.,),
    'optimizer_args':{
        'learningRate':0.25,
        'minStep':0.,
        'numberOfIterations':400,
    },
    'metric':'C',
}

steps = [('ransac', ransac_kwargs,),
         ('affine', affine_kwargs,),]

blocksize = [256, 256, 256]

cluster_kwargs = {
    'project':'scicompsoft',
    'ncpus':1,
    'threads':1,
    'min_workers':1,
    'max_workers':1,
}

# align
deform = distributed_piecewise_alignment_pipeline(
    fix, mov,
    fix_spacing_s3,
    mov_spacing_s3,
    steps,
    blocksize,
    static_transform_list=[affine,],
    cluster_kwargs=cluster_kwargs,
)

# apply affine only
deform_aligned = apply_transform(
    fix, mov,
    fix_spacing_s3, mov_spacing_s3,
    transform_list=[affine, deform],
)

# write results
nrrd.write(outdir+'/deform.nrrd', deform, compression_level=2)
# nrrd.write(outdir+'/deformed.nrrd', deform_aligned.transpose(2,1,0), compression_level=2)
tifffile.imwrite(outdir+'/deformed.tiff', deform_aligned.transpose([2,1,0]))

# # load precomputed results
# deform, _ = nrrd.read(outdir+'/deform.nrrd')
# Out:
# /u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 38901 instead
#   warnings.warn(
# 2023-08-02 11:54:06,496 - distributed.nanny - ERROR - Failed to initialize worker
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,513 - distributed.nanny - ERROR - Failed to initialize worker
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,553 - distributed.nanny - ERROR - Failed to start process
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,563 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-y2tk9rcg', purging
# 2023-08-02 11:54:06,601 - distributed.nanny - ERROR - Failed to start process
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,603 - distributed.nanny - ERROR - Error in Nanny killing Worker subprocess
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 608, in close
#     await self.kill(timeout=timeout, reason=reason)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 391, in kill
#     await self.process.kill(reason=reason, timeout=0.8 * (deadline - time()))
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 819, in kill
#     assert process
# AssertionError
# 2023-08-02 11:54:06,604 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-t_yu38zb', purging
# 2023-08-02 11:54:06,545 - distributed.nanny - ERROR - Failed to initialize worker
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,567 - distributed.nanny - ERROR - Failed to initialize worker
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,609 - distributed.nanny - ERROR - Failed to initialize worker
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,659 - distributed.nanny - ERROR - Failed to start process
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,672 - distributed.nanny - ERROR - Failed to start process
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,721 - distributed.nanny - ERROR - Failed to start process
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,722 - distributed.nanny - ERROR - Error in Nanny killing Worker subprocess
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 608, in close
#     await self.kill(timeout=timeout, reason=reason)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 391, in kill
#     await self.process.kill(reason=reason, timeout=0.8 * (deadline - time()))
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 819, in kill
#     assert process
# AssertionError
# 2023-08-02 11:54:06,870 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-lmmeeggj', purging
# 2023-08-02 11:54:06,882 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-z09gswwk', purging
# 2023-08-02 11:54:06,883 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-i6pd3mhn', purging
# 2023-08-02 11:54:06,886 - distributed.nanny - ERROR - Failed to initialize worker
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,938 - distributed.nanny - ERROR - Failed to start process
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# Task exception was never retrieved
# future: <Task finished name='Task-421' coro=<_wrap_awaitable() done, defined at /u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py:124> exception=RuntimeError('Nanny failed to start.')>
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 537, in start
#     await wait_for(self.start_unsafe(), timeout=timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/utils.py", line 1878, in wait_for
#     return await asyncio.wait_for(fut, timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/asyncio/tasks.py", line 442, in wait_for
#     return await fut
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 369, in start_unsafe
#     response = await self.instantiate()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py", line 125, in _wrap_awaitable
#     return await aw
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 545, in start
#     raise RuntimeError(f"{type(self).__name__} failed to start.") from exc
# RuntimeError: Nanny failed to start.
# Task exception was never retrieved
# future: <Task finished name='Task-419' coro=<_wrap_awaitable() done, defined at /u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py:124> exception=RuntimeError('Nanny failed to start.')>
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 537, in start
#     await wait_for(self.start_unsafe(), timeout=timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/utils.py", line 1878, in wait_for
#     return await asyncio.wait_for(fut, timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/asyncio/tasks.py", line 442, in wait_for
#     return await fut
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 369, in start_unsafe
#     response = await self.instantiate()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py", line 125, in _wrap_awaitable
#     return await aw
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 545, in start
#     raise RuntimeError(f"{type(self).__name__} failed to start.") from exc
# RuntimeError: Nanny failed to start.
# Task exception was never retrieved
# future: <Task finished name='Task-424' coro=<_wrap_awaitable() done, defined at /u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py:124> exception=RuntimeError('Nanny failed to start.')>
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 537, in start
#     await wait_for(self.start_unsafe(), timeout=timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/utils.py", line 1878, in wait_for
#     return await asyncio.wait_for(fut, timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/asyncio/tasks.py", line 442, in wait_for
#     return await fut
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 369, in start_unsafe
#     response = await self.instantiate()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py", line 125, in _wrap_awaitable
#     return await aw
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 545, in start
#     raise RuntimeError(f"{type(self).__name__} failed to start.") from exc
# RuntimeError: Nanny failed to start.
# Task exception was never retrieved
# future: <Task finished name='Task-420' coro=<_wrap_awaitable() done, defined at /u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py:124> exception=RuntimeError('Nanny failed to start.')>
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 537, in start
#     await wait_for(self.start_unsafe(), timeout=timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/utils.py", line 1878, in wait_for
#     return await asyncio.wait_for(fut, timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/asyncio/tasks.py", line 442, in wait_for
#     return await fut
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 369, in start_unsafe
#     response = await self.instantiate()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py", line 125, in _wrap_awaitable
#     return await aw
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 545, in start
#     raise RuntimeError(f"{type(self).__name__} failed to start.") from exc
# RuntimeError: Nanny failed to start.
# Task exception was never retrieved
# future: <Task finished name='Task-422' coro=<_wrap_awaitable() done, defined at /u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py:124> exception=RuntimeError('Nanny failed to start.')>
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 537, in start
#     await wait_for(self.start_unsafe(), timeout=timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/utils.py", line 1878, in wait_for
#     return await asyncio.wait_for(fut, timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/asyncio/tasks.py", line 442, in wait_for
#     return await fut
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 369, in start_unsafe
#     response = await self.instantiate()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py", line 125, in _wrap_awaitable
#     return await aw
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 545, in start
#     raise RuntimeError(f"{type(self).__name__} failed to start.") from exc
# RuntimeError: Nanny failed to start.
# Task exception was never retrieved
# future: <Task finished name='Task-423' coro=<_wrap_awaitable() done, defined at /u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py:124> exception=RuntimeError('Nanny failed to start.')>
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 537, in start
#     await wait_for(self.start_unsafe(), timeout=timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/utils.py", line 1878, in wait_for
#     return await asyncio.wait_for(fut, timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/asyncio/tasks.py", line 442, in wait_for
#     return await fut
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 369, in start_unsafe
#     response = await self.instantiate()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py", line 125, in _wrap_awaitable
#     return await aw
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 545, in start
#     raise RuntimeError(f"{type(self).__name__} failed to start.") from exc
# RuntimeError: Nanny failed to start.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:39
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/ClusterWrap/decorator.py:21, in cluster.<locals>.create_or_pass_cluster(*args, **kwargs)
#      17 if cluster is None:
#      18
#      19     # get arguments and run function in cluster context
#      20     x = kwargs['cluster_kwargs'] if 'cluster_kwargs' in kwargs else {}
# ---> 21     with cluster_constructor(**x) as cluster:
#      22         kwargs['cluster'] = cluster
#      23         return func(*args, **kwargs)
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/ClusterWrap/clusters.py:200, in local_cluster.__init__(self, config, memory_limit, **kwargs)
#     197     kwargs["memory_limit"] = memory_limit
#     199 # set up cluster, connect scheduler/client
# --> 200 cluster = LocalCluster(**kwargs)
#     201 client = Client(cluster)
#     202 self.set_cluster(cluster)
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/local.py:253, in LocalCluster.__init__(self, name, n_workers, threads_per_worker, processes, loop, start, host, ip, scheduler_port, silence_logs, dashboard_address, worker_dashboard_address, diagnostics_port, services, worker_services, service_kwargs, asynchronous, security, protocol, blocked_handlers, interface, worker_class, scheduler_kwargs, scheduler_sync_interval, **worker_kwargs)
#     250 worker = {"cls": worker_class, "options": worker_kwargs}
#     251 workers = {i: worker for i in range(n_workers)}
# --> 253 super().__init__(
#     254     name=name,
#     255     scheduler=scheduler,
#     256     workers=workers,
#     257     worker=worker,
#     258     loop=loop,
#     259     asynchronous=asynchronous,
#     260     silence_logs=silence_logs,
#     261     security=security,
#     262     scheduler_sync_interval=scheduler_sync_interval,
#     263 )
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py:293, in SpecCluster.__init__(self, workers, scheduler, worker, asynchronous, loop, security, silence_logs, name, shutdown_on_close, scheduler_sync_interval)
#     291 self.sync(self._start)
#     292 try:
# --> 293     self.sync(self._correct_state)
#     294 except Exception:
#     295     self.sync(self.close)
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/utils.py:351, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     349     return future
#     350 else:
# --> 351     return sync(
#     352         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     353     )
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/utils.py:418, in sync(loop, func, callback_timeout, *args, **kwargs)
#     416 if error:
#     417     typ, exc, tb = error
# --> 418     raise exc.with_traceback(tb)
#     419 else:
#     420     return result
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/utils.py:391, in sync.<locals>.f()
#     389         future = wait_for(future, callback_timeout)
#     390     future = asyncio.ensure_future(future)
# --> 391     result = yield future
#     392 except Exception:
#     393     error = sys.exc_info()
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/tornado/gen.py:769, in Runner.run(self)
#     766 exc_info = None
#     768 try:
# --> 769     value = future.result()
#     770 except Exception:
#     771     exc_info = sys.exc_info()
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py:387, in SpecCluster._correct_state_internal(self)
#     385     for w in workers:
#     386         w._cluster = weakref.ref(self)
# --> 387         await w  # for tornado gen.coroutine support
#     388 self.workers.update(dict(zip(to_open, workers)))
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py:526, in Server.start(self)
#     524 if self.status == Status.failed:
#     525     assert self.__startup_exc is not None
# --> 526     raise self.__startup_exc
#     527 elif self.status != Status.init:
#     528     return self
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py:537, in Server.start(self)
#     534     self.__startup_exc = exc
#     536 try:
# --> 537     await wait_for(self.start_unsafe(), timeout=timeout)
#     538 except asyncio.TimeoutError as exc:
#     539     await _close_on_failure(exc)
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/utils.py:1878, in wait_for(fut, timeout)
#    1877 async def wait_for(fut: Awaitable[T], timeout: float) -> T:
# -> 1878     return await asyncio.wait_for(fut, timeout)
#
# File ~/.conda/envs/napari/lib/python3.9/asyncio/tasks.py:442, in wait_for(fut, timeout, loop)
#     437     warnings.warn("The loop argument is deprecated since Python 3.8, "
#     438                   "and scheduled for removal in Python 3.10.",
#     439                   DeprecationWarning, stacklevel=2)
#     441 if timeout is None:
# --> 442     return await fut
#     444 if timeout <= 0:
#     445     fut = ensure_future(fut, loop=loop)
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py:369, in Nanny.start_unsafe(self)
#     366     await self.plugin_add(plugin=plugin, name=name)
#     368 logger.info("        Start Nanny at: %r", self.address)
# --> 369 response = await self.instantiate()
#     371 if response != Status.running:
#     372     await self.close(reason="nanny-start-failed")
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py:443, in Nanny.instantiate(self)
#     441 else:
#     442     try:
# --> 443         result = await self.process.start()
#     444     except Exception:
#     445         logger.error("Failed to start process", exc_info=True)
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py:720, in WorkerProcess.start(self)
#     718     self.status = Status.failed
#     719 try:
# --> 720     msg = await self._wait_until_connected(uid)
#     721 except Exception:
#     722     # NOTE: doesn't wait for process to terminate, just for terminate signal to be sent
#     723     await self.process.terminate()
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py:868, in WorkerProcess._wait_until_connected(self, uid)
#     865     continue
#     867 if "exception" in msg:
# --> 868     raise msg["exception"]
#     869 else:
#     870     return msg
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py:919, in run()
#     917 failure_type: str | None = "initialize"
#     918 try:
# --> 919     worker = worker_factory()
#     920     failure_type = "start"
#     921     thread = threading.Thread(
#     922         target=functools.partial(
#     923             watch_stop_q,
#    (...)
#     928         daemon=True,
#     929     )
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py:767, in __init__()
#     727 handlers = {
#     728     "gather": self.gather,
#     729     "run": self.run,
#    (...)
#     751     "get_story": self.get_story,
#     752 }
#     754 stream_handlers = {
#     755     "close": self.close,
#     756     "cancel-compute": self._handle_remote_stimulus(CancelComputeEvent),
#    (...)
#     764     "remove-worker": self._handle_remove_worker,
#     765 }
# --> 767 ServerNode.__init__(
#     768     self,
#     769     handlers=handlers,
#     770     stream_handlers=stream_handlers,
#     771     connection_args=self.connection_args,
#     772     **kwargs,
#     773 )
#     774 self.memory_manager = WorkerMemoryManager(
#     775     self,
#     776     data=data,
#    (...)
#     781     memory_pause_fraction=memory_pause_fraction,
#     782 )
#     784 transfer_incoming_bytes_limit = math.inf
#
# TypeError: __init__() got an unexpected keyword argument 'project'

# %% [markdown]
# ### even more local

# %%
# %%time

# get global alignment channels
fix = fix_zarr['/c3/s3'][...]
mov = mov_zarr['/c3/s3'][...][:, ::-1, ::-1]  # moving image data is 180 degrees rotates about z axis

deform_kwargs = {
    'alignment_spacing':2.0,
    'shrink_factors':(2,),
    'smooth_sigmas':(4.,),
    'control_point_spacing':200.0,
    'control_point_levels':(1,),
    'optimizer_args':{
        'learningRate':2.5,
        'minStep':0.07,
        'numberOfIterations':75,
    },
    # 'metric':'C',  # correlation required too much memory, but the default MI worked well
}

steps = [('deform', deform_kwargs,),]
         
blocksize = [256, 256, 256]

cluster_kwargs = {
    'project':'scicompsoft',
    'ncpus':3,
    'threads':1,
    'min_workers':60,
    'max_workers':60,
    'config':{
        'distributed.worker.memory.target':0.9,
        'distributed.worker.memory.spill':0.9,
        'distributed.worker.memory.pause':0.9,
    },
}

# align
deform2 = distributed_piecewise_alignment_pipeline(
    fix, mov,
    fix_spacing_s3,
    mov_spacing_s3,
    steps,
    blocksize,
    static_transform_list=[affine, deform],
    cluster_kwargs=cluster_kwargs,
)

# apply affine only
deform2_aligned = apply_transform(
    fix, mov,
    fix_spacing_s3, mov_spacing_s3,
    transform_list=[affine, deform, deform2],
)
         
# write results
nrrd.write(outdir+'/deform2.nrrd', deform2, compression_level=2)
nrrd.write(outdir+'/deformed2.nrrd', deform2_aligned.transpose(2,1,0), compression_level=2)

# load precomputed results
deform2, _ = nrrd.read(outdir+'/deform2.nrrd')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:37
#
# NameError: name 'distributed_piecewise_alignment_pipeline' is not defined

# %% [markdown]
# ## Histogram equalize data to visualize alignment result better
# ---

# %%
# %%time

from skimage.exposure import equalize_adapthist, equalize_hist
from scipy.ndimage import gaussian_filter, grey_opening

fix_s3, _ = nrrd.read(outdir+'/fix_s3.nrrd')
deformed, _ = nrrd.read(outdir+'/deformed.nrrd')
deformed2, _ = nrrd.read(outdir+'/deformed2.nrrd')

fix_s3_corrected = equalize_hist(fix_s3, mask=(fix_s3 > 90))
fix_s3_corrected = np.round(fix_s3_corrected * 64000).astype(np.uint16)

deformed_corrected = equalize_hist(deformed, mask=(deformed > 90))
deformed_corrected = np.round(deformed_corrected * 64000).astype(np.uint16)

deformed2_corrected = equalize_hist(deformed2, mask=(deformed2 > 90))
deformed2_corrected = np.round(deformed2_corrected * 64000).astype(np.uint16)

nrrd.write(outdir+'/fix_s3_corrected.nrrd', fix_s3_corrected, compression_level=2)
nrrd.write(outdir+'/deformed_corrected.nrrd', deformed_corrected, compression_level=2)
nrrd.write(outdir+'/deformed2_corrected.nrrd', deformed2_corrected, compression_level=2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File <timed exec>:4
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/nrrd/reader.py:506, in read(filename, custom_field_map, index_order)
#     474 """Read a NRRD file and return the header and data
#     475
#     476 See :ref:`user-guide:Reading NRRD files` for more information on reading NRRD files.
#    (...)
#     502 :meth:`write`, :meth:`read_header`, :meth:`read_data`
#     503 """
#     505 """Read a NRRD file and return a tuple (data, header)."""
# --> 506 with open(filename, 'rb') as fh:
#     507     header = read_header(fh, custom_field_map)
#     508     data = read_data(header, fh, filename, index_order)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/u/home/f/f7xiesnm/project-zipursky/easifish/results/test_bigstream2/fix_s3.nrrd'
