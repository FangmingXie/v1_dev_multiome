# %% [markdown]
# # Inputs
# ---

# %%
import numpy as np, zarr, nrrd
# alignment functions
from bigstream.align import alignment_pipeline
from bigstream.transform import apply_transform
import tifffile

# %%
p = '/u/home/f/f7xiesnm/project-zipursky/easifish/lt186/outputs/'
outdir = '/u/home/f/f7xiesnm/project-zipursky/easifish/results/test_bigstream_lt186_r7tor6'
# !mkdir -p $outdir

# %%
fix_path = p + '/r6/stitching/export.n5'
mov_path = p + '/r7/stitching/export.n5'
exp_factor = 2  # replace this with the known expansion factor for your sample to use pre-expansion units

s1_scale = [1,2,2] # z,y,x
s3_scale = [4,8,8]
s4_scale = [9,16,16]

# load fix data and spacing
fix_zarr = zarr.open(store=zarr.N5Store(fix_path), mode='r')
fix_meta = fix_zarr.attrs.asdict()
fix_spacing = np.array(fix_meta['pixelResolution']['dimensions'][::-1]) / exp_factor
fix_spacing_s1 = fix_spacing * s1_scale 
fix_spacing_s3 = fix_spacing * s3_scale 
fix_spacing_s4 = fix_spacing * s4_scale 

# load mov data and spacing
mov_zarr = zarr.open(store=zarr.N5Store(mov_path), mode='r')
mov_meta = mov_zarr.attrs.asdict()
mov_spacing = np.array(mov_meta['pixelResolution']['dimensions'][::-1]) / exp_factor
mov_spacing_s1 = mov_spacing * s1_scale
mov_spacing_s3 = mov_spacing * s3_scale 
mov_spacing_s4 = mov_spacing * s4_scale 

# print spacings
print(fix_spacing, mov_spacing)
print(fix_spacing_s1, mov_spacing_s1)
print(fix_spacing_s3, mov_spacing_s3)
print(fix_spacing_s4, mov_spacing_s4)

# print shapes
print(fix_zarr['/c3/s0'].shape, mov_zarr['/c3/s0'].shape)
print(fix_zarr['/c3/s3'].shape, mov_zarr['/c3/s3'].shape)
print(fix_zarr['/c3/s4'].shape, mov_zarr['/c3/s4'].shape)

# # write some channels
# nrrd.write(outdir+'/fix.nrrd', fix_zarr['/c3/s4'][...].transpose(2,1,0), compression_level=2)
# nrrd.write(outdir+'/mov.nrrd', mov_zarr['/c3/s4'][...].transpose(2,1,0), compression_level=2)
# Out:
# [0.21  0.115 0.115] [0.21  0.115 0.115]
# [0.21 0.23 0.23] [0.21 0.23 0.23]
# [0.84 0.92 0.92] [0.84 0.92 0.92]
# [1.89 1.84 1.84] [1.89 1.84 1.84]
# (2498, 7414, 9085) (2296, 7336, 9091)
# (624, 926, 1135) (574, 917, 1136)
# (277, 463, 567) (255, 458, 568)

# %% [markdown]
# # Alignment
# ---

# %% [markdown]
# ### global

# %%
# alignment functions
from bigstream.align import alignment_pipeline
from bigstream.transform import apply_transform

# %%
# get global alignment channels
fix = fix_zarr['/c3/s4'][...]
mov = mov_zarr['/c3/s4'][...]

# create some masks to focus alignment only on planes below the large artifact at the top
fix_mask = np.ones(fix.shape, dtype=np.uint8)
fix_mask[:65] = 0
fix_mask[-40:] = 0

mov_mask = np.ones(mov.shape, dtype=np.uint8)
mov_mask[:45] = 0
mov_mask[-40:] = 0

# %%
tifffile.imwrite(outdir+'/fix.tiff', fix)
tifffile.imwrite(outdir+'/mov.tiff', mov)

# %%
# %%time

# define alignment steps
ransac_kwargs = {
    'blob_sizes':[2, 8],
    'cc_radius':12,
    'match_threshold':0.4,
    'nspots':10000,
}

affine_kwargs = {
    'alignment_spacing':4.0,
    'shrink_factors':(1,),
    'smooth_sigmas':(4.,),
    'optimizer_args':{
        'learningRate':0.25,
        'minStep':0.,
        'numberOfIterations':400,
    },
    'metric':'C',
}


steps = [('ransac', ransac_kwargs,),
         ('affine', affine_kwargs,),]

# align
affine = alignment_pipeline(
    fix, mov,
    fix_spacing_s4,
    mov_spacing_s4,
    steps,
    # fix_mask=fix_mask,
    # mov_mask=mov_mask,
)

# apply affine only
affine_aligned = apply_transform(
    fix, mov,
    fix_spacing_s4, mov_spacing_s4,
    transform_list=[affine,],
)

# write results
np.savetxt(outdir+'/affine.mat', affine)
# nrrd.write(outdir+'/affine.nrrd', affine_aligned.transpose(2,1,0), compression_level=2)
tifffile.imwrite(outdir+'/affine.tiff', affine_aligned)

# # load precomputed results
# affine = np.loadtxt(outdir+'/affine.mat')
# Out:
# computing fixed spots
# found 18 fixed spots
# insufficient fixed spots found, returning default
# LEVEL:  0  ITERATION:  0  METRIC:  -0.004523220511760084
# LEVEL:  0  ITERATION:  1  METRIC:  -0.004753239363514043
# LEVEL:  0  ITERATION:  2  METRIC:  -0.004946603312618417
# LEVEL:  0  ITERATION:  3  METRIC:  -0.005095567924228569
# LEVEL:  0  ITERATION:  4  METRIC:  -0.005217559285850455
# LEVEL:  0  ITERATION:  5  METRIC:  -0.005277923568242368
# LEVEL:  0  ITERATION:  6  METRIC:  -0.005243936673782796
# LEVEL:  0  ITERATION:  7  METRIC:  -0.005168854850129974
# LEVEL:  0  ITERATION:  8  METRIC:  -0.005168534889068563
# LEVEL:  0  ITERATION:  9  METRIC:  -0.005303475304598708
# LEVEL:  0  ITERATION:  10  METRIC:  -0.005408517650069773
# LEVEL:  0  ITERATION:  11  METRIC:  -0.005479145974150027
# LEVEL:  0  ITERATION:  12  METRIC:  -0.005499441536990723
# LEVEL:  0  ITERATION:  13  METRIC:  -0.0054566041456718915
# LEVEL:  0  ITERATION:  14  METRIC:  -0.0053450128177057275
# LEVEL:  0  ITERATION:  15  METRIC:  -0.0052139034876105
# LEVEL:  0  ITERATION:  16  METRIC:  -0.005218640048098486
# LEVEL:  0  ITERATION:  17  METRIC:  -0.005324841073263881
# LEVEL:  0  ITERATION:  18  METRIC:  -0.0054718230133378966
# LEVEL:  0  ITERATION:  19  METRIC:  -0.005709043684950205
# LEVEL:  0  ITERATION:  20  METRIC:  -0.005808299569243997
# LEVEL:  0  ITERATION:  21  METRIC:  -0.005914597848744271
# LEVEL:  0  ITERATION:  22  METRIC:  -0.0059291058337998795
# LEVEL:  0  ITERATION:  23  METRIC:  -0.0058803442163918255
# LEVEL:  0  ITERATION:  24  METRIC:  -0.005968934842308147
# LEVEL:  0  ITERATION:  25  METRIC:  -0.0061223869117041285
# LEVEL:  0  ITERATION:  26  METRIC:  -0.006219692355915576
# LEVEL:  0  ITERATION:  27  METRIC:  -0.006264924213874959
# LEVEL:  0  ITERATION:  28  METRIC:  -0.006246174613425086
# LEVEL:  0  ITERATION:  29  METRIC:  -0.006174817688109442
# LEVEL:  0  ITERATION:  390  METRIC:  -0.6747273863002878
# LEVEL:  0  ITERATION:  391  METRIC:  -0.6748830867945385
# LEVEL:  0  ITERATION:  392  METRIC:  -0.67503975389967
# LEVEL:  0  ITERATION:  393  METRIC:  -0.6751982606851203
# LEVEL:  0  ITERATION:  394  METRIC:  -0.6753579266924036
# LEVEL:  0  ITERATION:  395  METRIC:  -0.6755163502252819
# LEVEL:  0  ITERATION:  396  METRIC:  -0.6756731885429571
# LEVEL:  0  ITERATION:  397  METRIC:  -0.6758287548854295
# LEVEL:  0  ITERATION:  398  METRIC:  -0.6759822588876742
# LEVEL:  0  ITERATION:  399  METRIC:  -0.6761332521023617
# Registration succeeded
# CPU times: user 50min 6s, sys: 27 s, total: 50min 33s
# Wall time: 3min 34s

# %%
fix2 = fix.copy()
mov2 = mov.copy()
fix2[:65] = 0
fix2[-40:] = 0
mov2[:45] = 0
mov2[-40:] = 0

# %%
# %%time

# define alignment steps
ransac_kwargs = {
    'blob_sizes':[2, 8],
    'cc_radius':12,
    'match_threshold':0.4,
    'nspots':10000,
}

affine_kwargs = {
    'alignment_spacing':4.0,
    'shrink_factors':(1,),
    'smooth_sigmas':(4.,),
    'optimizer_args':{
        'learningRate':0.25,
        'minStep':0.,
        'numberOfIterations':400,
    },
    'metric':'C',
}


steps = [('ransac', ransac_kwargs,),
         ('affine', affine_kwargs,),]

# align
affine = alignment_pipeline(
    fix2, mov2,
    fix_spacing_s4,
    mov_spacing_s4,
    steps,
    # fix_mask=fix_mask,
    # mov_mask=mov_mask,
)

# apply affine only
affine_aligned = apply_transform(
    fix2, mov2,
    fix_spacing_s4, mov_spacing_s4,
    transform_list=[affine,],
)

# write results
np.savetxt(outdir+'/affine-masked.mat', affine)
# nrrd.write(outdir+'/affine.nrrd', affine_aligned.transpose(2,1,0), compression_level=2)
tifffile.imwrite(outdir+'/affine-masked.tiff', affine_aligned)

# # load precomputed results
# affine = np.loadtxt(outdir+'/affine.mat')
# Out:
# computing fixed spots
# found 7 fixed spots
# insufficient fixed spots found, returning default
# LEVEL:  0  ITERATION:  0  METRIC:  -0.4065032750717284
# LEVEL:  0  ITERATION:  1  METRIC:  -0.4112308735352301
# LEVEL:  0  ITERATION:  2  METRIC:  -0.41566770897628347
# LEVEL:  0  ITERATION:  3  METRIC:  -0.420501459731569
# LEVEL:  0  ITERATION:  4  METRIC:  -0.4311946290842909
# LEVEL:  0  ITERATION:  5  METRIC:  -0.43665644411803883
# LEVEL:  0  ITERATION:  6  METRIC:  -0.44059679802799195
# LEVEL:  0  ITERATION:  7  METRIC:  -0.4420057936984635
# LEVEL:  0  ITERATION:  8  METRIC:  -0.4457777331599808
# LEVEL:  0  ITERATION:  9  METRIC:  -0.4507852133025236
# LEVEL:  0  ITERATION:  10  METRIC:  -0.4554976597955521
# LEVEL:  0  ITERATION:  11  METRIC:  -0.46225920604808196
# LEVEL:  0  ITERATION:  12  METRIC:  -0.46945366825746393
# LEVEL:  0  ITERATION:  13  METRIC:  -0.476970610506661
# LEVEL:  0  ITERATION:  14  METRIC:  -0.48289980617460165
# LEVEL:  0  ITERATION:  105  METRIC:  -0.8643174734025082
# LEVEL:  0  ITERATION:  106  METRIC:  -0.8643195017774322
# LEVEL:  0  ITERATION:  107  METRIC:  -0.8644097133017548
# LEVEL:  0  ITERATION:  108  METRIC:  -0.864458882040447
# LEVEL:  0  ITERATION:  109  METRIC:  -0.8644015588841599
# LEVEL:  0  ITERATION:  110  METRIC:  -0.8645679431774616
# LEVEL:  0  ITERATION:  111  METRIC:  -0.8644502237627313
# LEVEL:  0  ITERATION:  112  METRIC:  -0.8647366232274958
# LEVEL:  0  ITERATION:  113  METRIC:  -0.8645137584364913
# LEVEL:  0  ITERATION:  114  METRIC:  -0.8649003295258743
# Registration succeeded
# CPU times: user 22min 36s, sys: 25 s, total: 23min 1s
# Wall time: 3min 42s

# %% [markdown]
# ### local

# %%
from bigstream.piecewise_align import distributed_piecewise_alignment_pipeline
from bigstream.transform import apply_transform

import importlib
import bigstream
import bigstream.piecewise_align
importlib.reload(bigstream.piecewise_align)
# Out:
# <module 'bigstream.piecewise_align' from '/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/bigstream/piecewise_align.py'>

# %%
# %%time

# get global alignment channels
fix = fix_zarr['/c3/s3'][...]
mov = mov_zarr['/c3/s3'][...][:, ::-1, ::-1]  # moving image data is 180 degrees rotates about z axis

# define alignment steps
ransac_kwargs = {
    'blob_sizes':[4, 16],
    'cc_radius':16,
    'match_threshold':0.4,
    'nspots':4000,
}

affine_kwargs = {
    'alignment_spacing':2.0,
    'shrink_factors':(2,),
    'smooth_sigmas':(4.,),
    'optimizer_args':{
        'learningRate':0.25,
        'minStep':0.,
        'numberOfIterations':400,
    },
    'metric':'C',
}

steps = [('ransac', ransac_kwargs,),
         ('affine', affine_kwargs,),]

blocksize = [256, 256, 256]

cluster_kwargs = {
    'project':'scicompsoft',
    'ncpus':1,
    'threads':1,
    'min_workers':1,
    'max_workers':1,
}

# align
deform = distributed_piecewise_alignment_pipeline(
    fix, mov,
    fix_spacing_s3,
    mov_spacing_s3,
    steps,
    blocksize,
    static_transform_list=[affine,],
    cluster_kwargs=cluster_kwargs,
)

# apply affine only
deform_aligned = apply_transform(
    fix, mov,
    fix_spacing_s3, mov_spacing_s3,
    transform_list=[affine, deform],
)

# write results
nrrd.write(outdir+'/deform.nrrd', deform, compression_level=2)
# nrrd.write(outdir+'/deformed.nrrd', deform_aligned.transpose(2,1,0), compression_level=2)
tifffile.imwrite(outdir+'/deformed.tiff', deform_aligned.transpose([2,1,0]))

# # load precomputed results
# deform, _ = nrrd.read(outdir+'/deform.nrrd')
# Out:
# /u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 38901 instead
#   warnings.warn(
# 2023-08-02 11:54:06,496 - distributed.nanny - ERROR - Failed to initialize worker
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,513 - distributed.nanny - ERROR - Failed to initialize worker
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,553 - distributed.nanny - ERROR - Failed to start process
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,563 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-y2tk9rcg', purging
# 2023-08-02 11:54:06,601 - distributed.nanny - ERROR - Failed to start process
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,603 - distributed.nanny - ERROR - Error in Nanny killing Worker subprocess
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 608, in close
#     await self.kill(timeout=timeout, reason=reason)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 391, in kill
#     await self.process.kill(reason=reason, timeout=0.8 * (deadline - time()))
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 819, in kill
#     assert process
# AssertionError
# 2023-08-02 11:54:06,604 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-t_yu38zb', purging
# 2023-08-02 11:54:06,545 - distributed.nanny - ERROR - Failed to initialize worker
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,567 - distributed.nanny - ERROR - Failed to initialize worker
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,609 - distributed.nanny - ERROR - Failed to initialize worker
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,659 - distributed.nanny - ERROR - Failed to start process
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,672 - distributed.nanny - ERROR - Failed to start process
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,721 - distributed.nanny - ERROR - Failed to start process
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,722 - distributed.nanny - ERROR - Error in Nanny killing Worker subprocess
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 608, in close
#     await self.kill(timeout=timeout, reason=reason)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 391, in kill
#     await self.process.kill(reason=reason, timeout=0.8 * (deadline - time()))
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 819, in kill
#     assert process
# AssertionError
# 2023-08-02 11:54:06,870 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-lmmeeggj', purging
# 2023-08-02 11:54:06,882 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-z09gswwk', purging
# 2023-08-02 11:54:06,883 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-i6pd3mhn', purging
# 2023-08-02 11:54:06,886 - distributed.nanny - ERROR - Failed to initialize worker
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# 2023-08-02 11:54:06,938 - distributed.nanny - ERROR - Failed to start process
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
# Task exception was never retrieved
# future: <Task finished name='Task-421' coro=<_wrap_awaitable() done, defined at /u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py:124> exception=RuntimeError('Nanny failed to start.')>
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 537, in start
#     await wait_for(self.start_unsafe(), timeout=timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/utils.py", line 1878, in wait_for
#     return await asyncio.wait_for(fut, timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/asyncio/tasks.py", line 442, in wait_for
#     return await fut
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 369, in start_unsafe
#     response = await self.instantiate()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py", line 125, in _wrap_awaitable
#     return await aw
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 545, in start
#     raise RuntimeError(f"{type(self).__name__} failed to start.") from exc
# RuntimeError: Nanny failed to start.
# Task exception was never retrieved
# future: <Task finished name='Task-419' coro=<_wrap_awaitable() done, defined at /u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py:124> exception=RuntimeError('Nanny failed to start.')>
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 537, in start
#     await wait_for(self.start_unsafe(), timeout=timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/utils.py", line 1878, in wait_for
#     return await asyncio.wait_for(fut, timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/asyncio/tasks.py", line 442, in wait_for
#     return await fut
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 369, in start_unsafe
#     response = await self.instantiate()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py", line 125, in _wrap_awaitable
#     return await aw
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 545, in start
#     raise RuntimeError(f"{type(self).__name__} failed to start.") from exc
# RuntimeError: Nanny failed to start.
# Task exception was never retrieved
# future: <Task finished name='Task-424' coro=<_wrap_awaitable() done, defined at /u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py:124> exception=RuntimeError('Nanny failed to start.')>
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 537, in start
#     await wait_for(self.start_unsafe(), timeout=timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/utils.py", line 1878, in wait_for
#     return await asyncio.wait_for(fut, timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/asyncio/tasks.py", line 442, in wait_for
#     return await fut
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 369, in start_unsafe
#     response = await self.instantiate()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py", line 125, in _wrap_awaitable
#     return await aw
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 545, in start
#     raise RuntimeError(f"{type(self).__name__} failed to start.") from exc
# RuntimeError: Nanny failed to start.
# Task exception was never retrieved
# future: <Task finished name='Task-420' coro=<_wrap_awaitable() done, defined at /u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py:124> exception=RuntimeError('Nanny failed to start.')>
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 537, in start
#     await wait_for(self.start_unsafe(), timeout=timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/utils.py", line 1878, in wait_for
#     return await asyncio.wait_for(fut, timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/asyncio/tasks.py", line 442, in wait_for
#     return await fut
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 369, in start_unsafe
#     response = await self.instantiate()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py", line 125, in _wrap_awaitable
#     return await aw
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 545, in start
#     raise RuntimeError(f"{type(self).__name__} failed to start.") from exc
# RuntimeError: Nanny failed to start.
# Task exception was never retrieved
# future: <Task finished name='Task-422' coro=<_wrap_awaitable() done, defined at /u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py:124> exception=RuntimeError('Nanny failed to start.')>
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 537, in start
#     await wait_for(self.start_unsafe(), timeout=timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/utils.py", line 1878, in wait_for
#     return await asyncio.wait_for(fut, timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/asyncio/tasks.py", line 442, in wait_for
#     return await fut
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 369, in start_unsafe
#     response = await self.instantiate()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py", line 125, in _wrap_awaitable
#     return await aw
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 545, in start
#     raise RuntimeError(f"{type(self).__name__} failed to start.") from exc
# RuntimeError: Nanny failed to start.
# Task exception was never retrieved
# future: <Task finished name='Task-423' coro=<_wrap_awaitable() done, defined at /u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py:124> exception=RuntimeError('Nanny failed to start.')>
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 537, in start
#     await wait_for(self.start_unsafe(), timeout=timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/utils.py", line 1878, in wait_for
#     return await asyncio.wait_for(fut, timeout)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/asyncio/tasks.py", line 442, in wait_for
#     return await fut
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 369, in start_unsafe
#     response = await self.instantiate()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 443, in instantiate
#     result = await self.process.start()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 720, in start
#     msg = await self._wait_until_connected(uid)
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 868, in _wait_until_connected
#     raise msg["exception"]
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py", line 919, in run
#     worker = worker_factory()
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py", line 767, in __init__
#     ServerNode.__init__(
# TypeError: __init__() got an unexpected keyword argument 'project'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py", line 125, in _wrap_awaitable
#     return await aw
#   File "/u/home/f/f7xiesnm/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py", line 545, in start
#     raise RuntimeError(f"{type(self).__name__} failed to start.") from exc
# RuntimeError: Nanny failed to start.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:39
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/ClusterWrap/decorator.py:21, in cluster.<locals>.create_or_pass_cluster(*args, **kwargs)
#      17 if cluster is None:
#      18
#      19     # get arguments and run function in cluster context
#      20     x = kwargs['cluster_kwargs'] if 'cluster_kwargs' in kwargs else {}
# ---> 21     with cluster_constructor(**x) as cluster:
#      22         kwargs['cluster'] = cluster
#      23         return func(*args, **kwargs)
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/ClusterWrap/clusters.py:200, in local_cluster.__init__(self, config, memory_limit, **kwargs)
#     197     kwargs["memory_limit"] = memory_limit
#     199 # set up cluster, connect scheduler/client
# --> 200 cluster = LocalCluster(**kwargs)
#     201 client = Client(cluster)
#     202 self.set_cluster(cluster)
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/local.py:253, in LocalCluster.__init__(self, name, n_workers, threads_per_worker, processes, loop, start, host, ip, scheduler_port, silence_logs, dashboard_address, worker_dashboard_address, diagnostics_port, services, worker_services, service_kwargs, asynchronous, security, protocol, blocked_handlers, interface, worker_class, scheduler_kwargs, scheduler_sync_interval, **worker_kwargs)
#     250 worker = {"cls": worker_class, "options": worker_kwargs}
#     251 workers = {i: worker for i in range(n_workers)}
# --> 253 super().__init__(
#     254     name=name,
#     255     scheduler=scheduler,
#     256     workers=workers,
#     257     worker=worker,
#     258     loop=loop,
#     259     asynchronous=asynchronous,
#     260     silence_logs=silence_logs,
#     261     security=security,
#     262     scheduler_sync_interval=scheduler_sync_interval,
#     263 )
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py:293, in SpecCluster.__init__(self, workers, scheduler, worker, asynchronous, loop, security, silence_logs, name, shutdown_on_close, scheduler_sync_interval)
#     291 self.sync(self._start)
#     292 try:
# --> 293     self.sync(self._correct_state)
#     294 except Exception:
#     295     self.sync(self.close)
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/utils.py:351, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     349     return future
#     350 else:
# --> 351     return sync(
#     352         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     353     )
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/utils.py:418, in sync(loop, func, callback_timeout, *args, **kwargs)
#     416 if error:
#     417     typ, exc, tb = error
# --> 418     raise exc.with_traceback(tb)
#     419 else:
#     420     return result
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/utils.py:391, in sync.<locals>.f()
#     389         future = wait_for(future, callback_timeout)
#     390     future = asyncio.ensure_future(future)
# --> 391     result = yield future
#     392 except Exception:
#     393     error = sys.exc_info()
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/tornado/gen.py:769, in Runner.run(self)
#     766 exc_info = None
#     768 try:
# --> 769     value = future.result()
#     770 except Exception:
#     771     exc_info = sys.exc_info()
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/deploy/spec.py:387, in SpecCluster._correct_state_internal(self)
#     385     for w in workers:
#     386         w._cluster = weakref.ref(self)
# --> 387         await w  # for tornado gen.coroutine support
#     388 self.workers.update(dict(zip(to_open, workers)))
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py:526, in Server.start(self)
#     524 if self.status == Status.failed:
#     525     assert self.__startup_exc is not None
# --> 526     raise self.__startup_exc
#     527 elif self.status != Status.init:
#     528     return self
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/core.py:537, in Server.start(self)
#     534     self.__startup_exc = exc
#     536 try:
# --> 537     await wait_for(self.start_unsafe(), timeout=timeout)
#     538 except asyncio.TimeoutError as exc:
#     539     await _close_on_failure(exc)
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/utils.py:1878, in wait_for(fut, timeout)
#    1877 async def wait_for(fut: Awaitable[T], timeout: float) -> T:
# -> 1878     return await asyncio.wait_for(fut, timeout)
#
# File ~/.conda/envs/napari/lib/python3.9/asyncio/tasks.py:442, in wait_for(fut, timeout, loop)
#     437     warnings.warn("The loop argument is deprecated since Python 3.8, "
#     438                   "and scheduled for removal in Python 3.10.",
#     439                   DeprecationWarning, stacklevel=2)
#     441 if timeout is None:
# --> 442     return await fut
#     444 if timeout <= 0:
#     445     fut = ensure_future(fut, loop=loop)
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py:369, in Nanny.start_unsafe(self)
#     366     await self.plugin_add(plugin=plugin, name=name)
#     368 logger.info("        Start Nanny at: %r", self.address)
# --> 369 response = await self.instantiate()
#     371 if response != Status.running:
#     372     await self.close(reason="nanny-start-failed")
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py:443, in Nanny.instantiate(self)
#     441 else:
#     442     try:
# --> 443         result = await self.process.start()
#     444     except Exception:
#     445         logger.error("Failed to start process", exc_info=True)
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py:720, in WorkerProcess.start(self)
#     718     self.status = Status.failed
#     719 try:
# --> 720     msg = await self._wait_until_connected(uid)
#     721 except Exception:
#     722     # NOTE: doesn't wait for process to terminate, just for terminate signal to be sent
#     723     await self.process.terminate()
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py:868, in WorkerProcess._wait_until_connected(self, uid)
#     865     continue
#     867 if "exception" in msg:
# --> 868     raise msg["exception"]
#     869 else:
#     870     return msg
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/nanny.py:919, in run()
#     917 failure_type: str | None = "initialize"
#     918 try:
# --> 919     worker = worker_factory()
#     920     failure_type = "start"
#     921     thread = threading.Thread(
#     922         target=functools.partial(
#     923             watch_stop_q,
#    (...)
#     928         daemon=True,
#     929     )
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/distributed/worker.py:767, in __init__()
#     727 handlers = {
#     728     "gather": self.gather,
#     729     "run": self.run,
#    (...)
#     751     "get_story": self.get_story,
#     752 }
#     754 stream_handlers = {
#     755     "close": self.close,
#     756     "cancel-compute": self._handle_remote_stimulus(CancelComputeEvent),
#    (...)
#     764     "remove-worker": self._handle_remove_worker,
#     765 }
# --> 767 ServerNode.__init__(
#     768     self,
#     769     handlers=handlers,
#     770     stream_handlers=stream_handlers,
#     771     connection_args=self.connection_args,
#     772     **kwargs,
#     773 )
#     774 self.memory_manager = WorkerMemoryManager(
#     775     self,
#     776     data=data,
#    (...)
#     781     memory_pause_fraction=memory_pause_fraction,
#     782 )
#     784 transfer_incoming_bytes_limit = math.inf
#
# TypeError: __init__() got an unexpected keyword argument 'project'

# %% [markdown]
# ### even more local

# %%
# %%time

# get global alignment channels
fix = fix_zarr['/c3/s3'][...]
mov = mov_zarr['/c3/s3'][...][:, ::-1, ::-1]  # moving image data is 180 degrees rotates about z axis

deform_kwargs = {
    'alignment_spacing':2.0,
    'shrink_factors':(2,),
    'smooth_sigmas':(4.,),
    'control_point_spacing':200.0,
    'control_point_levels':(1,),
    'optimizer_args':{
        'learningRate':2.5,
        'minStep':0.07,
        'numberOfIterations':75,
    },
    # 'metric':'C',  # correlation required too much memory, but the default MI worked well
}

steps = [('deform', deform_kwargs,),]
         
blocksize = [256, 256, 256]

cluster_kwargs = {
    'project':'scicompsoft',
    'ncpus':3,
    'threads':1,
    'min_workers':60,
    'max_workers':60,
    'config':{
        'distributed.worker.memory.target':0.9,
        'distributed.worker.memory.spill':0.9,
        'distributed.worker.memory.pause':0.9,
    },
}

# align
deform2 = distributed_piecewise_alignment_pipeline(
    fix, mov,
    fix_spacing_s3,
    mov_spacing_s3,
    steps,
    blocksize,
    static_transform_list=[affine, deform],
    cluster_kwargs=cluster_kwargs,
)

# apply affine only
deform2_aligned = apply_transform(
    fix, mov,
    fix_spacing_s3, mov_spacing_s3,
    transform_list=[affine, deform, deform2],
)
         
# write results
nrrd.write(outdir+'/deform2.nrrd', deform2, compression_level=2)
nrrd.write(outdir+'/deformed2.nrrd', deform2_aligned.transpose(2,1,0), compression_level=2)

# load precomputed results
deform2, _ = nrrd.read(outdir+'/deform2.nrrd')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:37
#
# NameError: name 'distributed_piecewise_alignment_pipeline' is not defined

# %% [markdown]
# ## Histogram equalize data to visualize alignment result better
# ---

# %%
# %%time

from skimage.exposure import equalize_adapthist, equalize_hist
from scipy.ndimage import gaussian_filter, grey_opening

fix_s3, _ = nrrd.read(outdir+'/fix_s3.nrrd')
deformed, _ = nrrd.read(outdir+'/deformed.nrrd')
deformed2, _ = nrrd.read(outdir+'/deformed2.nrrd')

fix_s3_corrected = equalize_hist(fix_s3, mask=(fix_s3 > 90))
fix_s3_corrected = np.round(fix_s3_corrected * 64000).astype(np.uint16)

deformed_corrected = equalize_hist(deformed, mask=(deformed > 90))
deformed_corrected = np.round(deformed_corrected * 64000).astype(np.uint16)

deformed2_corrected = equalize_hist(deformed2, mask=(deformed2 > 90))
deformed2_corrected = np.round(deformed2_corrected * 64000).astype(np.uint16)

nrrd.write(outdir+'/fix_s3_corrected.nrrd', fix_s3_corrected, compression_level=2)
nrrd.write(outdir+'/deformed_corrected.nrrd', deformed_corrected, compression_level=2)
nrrd.write(outdir+'/deformed2_corrected.nrrd', deformed2_corrected, compression_level=2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File <timed exec>:4
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/nrrd/reader.py:506, in read(filename, custom_field_map, index_order)
#     474 """Read a NRRD file and return the header and data
#     475
#     476 See :ref:`user-guide:Reading NRRD files` for more information on reading NRRD files.
#    (...)
#     502 :meth:`write`, :meth:`read_header`, :meth:`read_data`
#     503 """
#     505 """Read a NRRD file and return a tuple (data, header)."""
# --> 506 with open(filename, 'rb') as fh:
#     507     header = read_header(fh, custom_field_map)
#     508     data = read_data(header, fh, filename, index_order)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/u/home/f/f7xiesnm/project-zipursky/easifish/results/test_bigstream2/fix_s3.nrrd'
