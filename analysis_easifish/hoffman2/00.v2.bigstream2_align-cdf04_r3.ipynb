# %% [markdown]
# # Inputs
# ---

# %%
import numpy as np, zarr, nrrd
# alignment functions
from bigstream.align import alignment_pipeline
from bigstream.transform import apply_transform
import tifffile
import seaborn as sns

# %%
p      = '/u/home/f/f7xiesnm/project-zipursky/easifish/cdf04_c1-2_bino/outputs/'
outdir = '/u/home/f/f7xiesnm/project-zipursky/easifish/results/test_bigstream_cdf04_r3tor1'
# !mkdir -p $outdir

# %%
fix_path = p + '/r1/stitching/export.n5'
mov_path = p + '/r3/stitching/export.n5'
exp_factor = 2  # replace this with the known expansion factor for your sample to use pre-expansion units

fix_spacing = np.array([0.42, 0.23, 0.23]) / exp_factor
mov_spacing = np.array([0.42, 0.23, 0.23]) / exp_factor
s1_scale = [1,2,2] # z,y,x
s3_scale = [4,8,8]
s4_scale = [8,16,16]

# load fix data and spacing
fix_zarr = zarr.open(store=zarr.N5Store(fix_path), mode='r')
# fix_meta = fix_zarr.attrs.asdict()
# fix_spacing = np.array(fix_meta['pixelResolution']['dimensions'][::-1]) / exp_factor
fix_spacing_s1 = fix_spacing * s1_scale 
fix_spacing_s3 = fix_spacing * s3_scale 
fix_spacing_s4 = fix_spacing * s4_scale 

# load mov data and spacing
mov_zarr = zarr.open(store=zarr.N5Store(mov_path), mode='r')
# mov_meta = mov_zarr.attrs.asdict()
# mov_spacing = np.array(mov_meta['pixelResolution']['dimensions'][::-1]) / exp_factor
mov_spacing_s1 = mov_spacing * s1_scale
mov_spacing_s3 = mov_spacing * s3_scale 
mov_spacing_s4 = mov_spacing * s4_scale 

# print spacings
print(fix_spacing, mov_spacing)
print(fix_spacing_s1, mov_spacing_s1)
print(fix_spacing_s3, mov_spacing_s3)
print(fix_spacing_s4, mov_spacing_s4)

# print shapes
print(fix_zarr['/c3_reg/s3'].shape, mov_zarr['/c3_reg/s3'].shape)
print(fix_zarr['/c3_reg/s4'].shape, mov_zarr['/c3_reg/s4'].shape)

# # write some channels
# nrrd.write(outdir+'/fix.nrrd', fix_zarr['/c3/s4'][...].transpose(2,1,0), compression_level=2)
# nrrd.write(outdir+'/mov.nrrd', mov_zarr['/c3/s4'][...].transpose(2,1,0), compression_level=2)
# Out:
# [0.21  0.115 0.115] [0.21  0.115 0.115]
# [0.21 0.23 0.23] [0.21 0.23 0.23]
# [0.84 0.92 0.92] [0.84 0.92 0.92]
# [1.68 1.84 1.84] [1.68 1.84 1.84]
# (530, 901, 906) (544, 903, 905)
# (265, 450, 453) (272, 451, 452)

# %% [markdown]
# # Alignment
# ---

# %% [markdown]
# ### global

# %%
# alignment functions
from bigstream.align import alignment_pipeline
from bigstream.transform import apply_transform

# %%
# get global alignment channels
fix = fix_zarr['/c3_reg/s4'][...]
mov = mov_zarr['/c3_reg/s4'][...] #[:,::-1,::-1]
fix[:50] = 0
fix[-20:] = 0
mov[:40] = 0
mov[-20:] = 0

# # create some masks to focus alignment only on planes below the large artifact at the top
# fix_mask = np.ones(fix.shape, dtype=np.uint8)
# fix_mask[:50] = 0
# fix_mask[-20:] = 0

# mov_mask = np.ones(mov.shape, dtype=np.uint8)
# mov_mask[:40] = 0
# mov_mask[-20:] = 0

# %%
tifffile.imwrite(outdir+'/fix.tiff', fix)
tifffile.imwrite(outdir+'/mov.tiff', mov)
# tifffile.imwrite(outdir+'/mov0.tiff', mov0)

# %%
# %%time

# define alignment steps
ransac_kwargs = {
    'blob_sizes': [2, 8],
    'cc_radius': 12,
    'match_threshold':0.4,
    'nspots':10000,
    # 'nspots':2000,
}

affine_kwargs = {
    'alignment_spacing':4.0,
    'shrink_factors':(1,),
    'smooth_sigmas':(4.,),
    'optimizer_args':{
        'learningRate':0.25,
        'minStep':0.,
        'numberOfIterations':400,
    },
    'metric':'C',
}


steps = [
    ('ransac', ransac_kwargs,),
    ('affine', affine_kwargs,),
        ]

# align
affine = alignment_pipeline(
    fix, mov,
    fix_spacing_s4,
    mov_spacing_s4,
    steps,
    # fix_mask=fix_mask,
    # mov_mask=mov_mask,
)
print(affine)



# apply affine only
affine_aligned = apply_transform(
    fix, mov,
    fix_spacing_s4, mov_spacing_s4,
    transform_list=[affine,],
)

# write results
np.savetxt(outdir+'/affine-masked.mat', affine)
tifffile.imwrite(outdir+'/affine-masked.tiff', affine_aligned)
# Out:
# computing fixed spots
# found 57465 fixed spots
# computing moving spots
# found 57640 moving spots
# sorting spots
# extracting contexts
# computing pairwise correlations
# 4900 matched spots
# aligning
# LEVEL:  0  ITERATION:  0  METRIC:  -0.39599961285457624
# LEVEL:  0  ITERATION:  1  METRIC:  -0.3973796749559185
# LEVEL:  0  ITERATION:  2  METRIC:  -0.39849941491568386
# LEVEL:  0  ITERATION:  3  METRIC:  -0.39939129820930114
# LEVEL:  0  ITERATION:  4  METRIC:  -0.4001222740244241
# LEVEL:  0  ITERATION:  5  METRIC:  -0.40083063548745546
# LEVEL:  0  ITERATION:  6  METRIC:  -0.4018180556991241
# LEVEL:  0  ITERATION:  7  METRIC:  -0.40389484147335686
# LEVEL:  0  ITERATION:  8  METRIC:  -0.40659004033532486
# LEVEL:  0  ITERATION:  9  METRIC:  -0.4083910321259059
# LEVEL:  0  ITERATION:  10  METRIC:  -0.40976403128648803
# LEVEL:  0  ITERATION:  11  METRIC:  -0.410477006519559
# LEVEL:  0  ITERATION:  12  METRIC:  -0.4113298910105011
# LEVEL:  0  ITERATION:  13  METRIC:  -0.41245799777742576
# LEVEL:  0  ITERATION:  14  METRIC:  -0.4132813374903021
# LEVEL:  0  ITERATION:  15  METRIC:  -0.41436114737119184
# LEVEL:  0  ITERATION:  16  METRIC:  -0.4150500450279337
# LEVEL:  0  ITERATION:  17  METRIC:  -0.4160670529290453
# LEVEL:  0  ITERATION:  18  METRIC:  -0.4165773782912367
# LEVEL:  0  ITERATION:  19  METRIC:  -0.41751626867901603
# LEVEL:  0  ITERATION:  20  METRIC:  -0.417901971329513
# LEVEL:  0  ITERATION:  21  METRIC:  -0.4187672987517546
# LEVEL:  0  ITERATION:  22  METRIC:  -0.41908232614668534
# LEVEL:  0  ITERATION:  23  METRIC:  -0.4198745047844731
# LEVEL:  0  ITERATION:  24  METRIC:  -0.4201287459512817
# LEVEL:  0  ITERATION:  25  METRIC:  -0.42086766427702027
# LEVEL:  0  ITERATION:  26  METRIC:  -0.4210819929170502
# LEVEL:  0  ITERATION:  27  METRIC:  -0.42176079309130476
# LEVEL:  0  ITERATION:  28  METRIC:  -0.4218588117172485
# LEVEL:  0  ITERATION:  29  METRIC:  -0.42204422304231204
# LEVEL:  0  ITERATION:  30  METRIC:  -0.42235067252770175
# LEVEL:  0  ITERATION:  31  METRIC:  -0.4225896350798739
# LEVEL:  0  ITERATION:  32  METRIC:  -0.42286993572815906
# LEVEL:  0  ITERATION:  33  METRIC:  -0.4230987576637244
# LEVEL:  0  ITERATION:  34  METRIC:  -0.4233564928675045
# LEVEL:  0  ITERATION:  35  METRIC:  -0.4235685583499126
# LEVEL:  0  ITERATION:  36  METRIC:  -0.42380764055221176
# LEVEL:  0  ITERATION:  37  METRIC:  -0.42400136932564747
# LEVEL:  0  ITERATION:  38  METRIC:  -0.42422056365594774
# LEVEL:  0  ITERATION:  39  METRIC:  -0.42439464046269765
# LEVEL:  0  ITERATION:  40  METRIC:  -0.4245959123289199
# LEVEL:  0  ITERATION:  41  METRIC:  -0.4247486224815621
# LEVEL:  0  ITERATION:  42  METRIC:  -0.42492854284378784
# LEVEL:  0  ITERATION:  43  METRIC:  -0.4250586999935829
# LEVEL:  0  ITERATION:  44  METRIC:  -0.4252151657902553
# LEVEL:  0  ITERATION:  45  METRIC:  -0.42532593415201414
# LEVEL:  0  ITERATION:  46  METRIC:  -0.425457155962618
# LEVEL:  0  ITERATION:  47  METRIC:  -0.42555754677504143
# LEVEL:  0  ITERATION:  48  METRIC:  -0.42566663307433583
# LEVEL:  0  ITERATION:  49  METRIC:  -0.42576088941891016
# LEVEL:  0  ITERATION:  50  METRIC:  -0.42585163428088113
# LEVEL:  0  ITERATION:  51  METRIC:  -0.42594164563521436
# LEVEL:  0  ITERATION:  52  METRIC:  -0.4260175584219159
# LEVEL:  0  ITERATION:  53  METRIC:  -0.42610386797198585
# LEVEL:  0  ITERATION:  54  METRIC:  -0.4261682471466246
# LEVEL:  0  ITERATION:  55  METRIC:  -0.42625217760866163
# LEVEL:  0  ITERATION:  56  METRIC:  -0.42630626564527263
# LEVEL:  0  ITERATION:  57  METRIC:  -0.4263878245784362
# LEVEL:  0  ITERATION:  58  METRIC:  -0.426434541282105
# LEVEL:  0  ITERATION:  59  METRIC:  -0.4265129052398488
# LEVEL:  0  ITERATION:  60  METRIC:  -0.4265542978831223
# LEVEL:  0  ITERATION:  61  METRIC:  -0.426629769940974
# LEVEL:  0  ITERATION:  62  METRIC:  -0.4266661282040788
# LEVEL:  0  ITERATION:  63  METRIC:  -0.42673817103304035
# LEVEL:  0  ITERATION:  64  METRIC:  -0.4267711681818891
# LEVEL:  0  ITERATION:  65  METRIC:  -0.4268388999107921
# LEVEL:  0  ITERATION:  66  METRIC:  -0.42686873437702
# LEVEL:  0  ITERATION:  67  METRIC:  -0.4269324001990644
# LEVEL:  0  ITERATION:  68  METRIC:  -0.4269601035358472
# LEVEL:  0  ITERATION:  69  METRIC:  -0.4270189932102756
# LEVEL:  0  ITERATION:  70  METRIC:  -0.4270444025227043
# LEVEL:  0  ITERATION:  71  METRIC:  -0.42707428673995834
# LEVEL:  0  ITERATION:  72  METRIC:  -0.42709434079318903
# LEVEL:  0  ITERATION:  73  METRIC:  -0.4271236170540445
# LEVEL:  0  ITERATION:  74  METRIC:  -0.42714760155586284
# LEVEL:  0  ITERATION:  75  METRIC:  -0.427174910733723
# LEVEL:  0  ITERATION:  76  METRIC:  -0.42719885776182076
# LEVEL:  0  ITERATION:  77  METRIC:  -0.42722447109689293
# LEVEL:  0  ITERATION:  78  METRIC:  -0.4272476641704988
# LEVEL:  0  ITERATION:  79  METRIC:  -0.4272715910369996
# LEVEL:  0  ITERATION:  80  METRIC:  -0.42729355651479656
# LEVEL:  0  ITERATION:  81  METRIC:  -0.42731643673352987
# LEVEL:  0  ITERATION:  82  METRIC:  -0.42733749237158386
# LEVEL:  0  ITERATION:  83  METRIC:  -0.4273591150665843
# LEVEL:  0  ITERATION:  84  METRIC:  -0.4273793599750198
# LEVEL:  0  ITERATION:  85  METRIC:  -0.4274000744005518
# LEVEL:  0  ITERATION:  86  METRIC:  -0.4274189566981225
# LEVEL:  0  ITERATION:  87  METRIC:  -0.4274384036241796
# LEVEL:  0  ITERATION:  88  METRIC:  -0.42745651793851064
# LEVEL:  0  ITERATION:  89  METRIC:  -0.42747523046663144
# LEVEL:  0  ITERATION:  90  METRIC:  -0.4274918402163629
# LEVEL:  0  ITERATION:  91  METRIC:  -0.42750993056320463
# LEVEL:  0  ITERATION:  92  METRIC:  -0.4275252606399135
# LEVEL:  0  ITERATION:  93  METRIC:  -0.42754238016447743
# LEVEL:  0  ITERATION:  94  METRIC:  -0.4275563292522828
# LEVEL:  0  ITERATION:  95  METRIC:  -0.4275733556965007
# LEVEL:  0  ITERATION:  96  METRIC:  -0.427585241332561
# LEVEL:  0  ITERATION:  97  METRIC:  -0.4276020323229189
# LEVEL:  0  ITERATION:  98  METRIC:  -0.42761084639343755
# LEVEL:  0  ITERATION:  99  METRIC:  -0.4276274242322521
# LEVEL:  0  ITERATION:  100  METRIC:  -0.4276350625174621
# LEVEL:  0  ITERATION:  101  METRIC:  -0.42765031492944916
# LEVEL:  0  ITERATION:  102  METRIC:  -0.4276565360768881
# LEVEL:  0  ITERATION:  103  METRIC:  -0.42767142529264934
# LEVEL:  0  ITERATION:  104  METRIC:  -0.42767657273419596
# LEVEL:  0  ITERATION:  105  METRIC:  -0.4276903496810779
# LEVEL:  0  ITERATION:  106  METRIC:  -0.427694771598012
# LEVEL:  0  ITERATION:  107  METRIC:  -0.4277085539528697
# LEVEL:  0  ITERATION:  108  METRIC:  -0.4277118670735989
# LEVEL:  0  ITERATION:  109  METRIC:  -0.4277249487920764
# LEVEL:  0  ITERATION:  110  METRIC:  -0.4277282239360841
# LEVEL:  0  ITERATION:  111  METRIC:  -0.4277399006197123
# LEVEL:  0  ITERATION:  112  METRIC:  -0.42774277698759366
# LEVEL:  0  ITERATION:  113  METRIC:  -0.4277548326891245
# LEVEL:  0  ITERATION:  114  METRIC:  -0.42775687344146235
# LEVEL:  0  ITERATION:  115  METRIC:  -0.4277662034041379
# LEVEL:  0  ITERATION:  116  METRIC:  -0.4277677363828997
# LEVEL:  0  ITERATION:  117  METRIC:  -0.4277791373312887
# LEVEL:  0  ITERATION:  118  METRIC:  -0.42778061275634577
# LEVEL:  0  ITERATION:  119  METRIC:  -0.42778579993274113
# LEVEL:  0  ITERATION:  120  METRIC:  -0.4277883755384769
# LEVEL:  0  ITERATION:  121  METRIC:  -0.4277925483524693
# LEVEL:  0  ITERATION:  122  METRIC:  -0.4277961402034969
# LEVEL:  0  ITERATION:  123  METRIC:  -0.4278002213753028
# LEVEL:  0  ITERATION:  124  METRIC:  -0.42780354030439527
# LEVEL:  0  ITERATION:  125  METRIC:  -0.42780694083044374
# LEVEL:  0  ITERATION:  126  METRIC:  -0.4278100042352422
# LEVEL:  0  ITERATION:  127  METRIC:  -0.42781261590678504
# Registration succeeded
# [[ 9.98977208e-01 -8.25082902e-02 -5.50222030e-02  4.44127655e+01]
#  [ 3.46331166e-02  1.02259374e+00  5.73210152e-02 -2.50151666e+01]
#  [ 4.78157726e-02 -1.18225957e-02  1.00977600e+00 -6.68159017e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# CPU times: user 19min 38s, sys: 31.4 s, total: 20min 10s
# Wall time: 9min 22s
