# %% [markdown]
# # Inputs
# ---

# %%
import numpy as np, zarr, nrrd
# alignment functions
from bigstream.align import alignment_pipeline
from bigstream.transform import apply_transform
import tifffile

import seaborn as sns
import matplotlib.pyplot as plt

# %%
p = '/u/home/f/f7xiesnm/project-zipursky/easifish/lt186/outputs/'
outdir = '/u/home/f/f7xiesnm/project-zipursky/easifish/results/test_bigstream_lt186_cap_v2'
# !mkdir -p $outdir

# %%
r1_path = p + '/r1/stitching/export.n5'
r2_path = p + '/r2/stitching/export.n5'
r6_path = p + '/r6/stitching/export.n5'
r7_path = p + '/r7/stitching/export.n5'

r1_zarr = zarr.open(store=zarr.N5Store(r1_path), mode='r')
r2_zarr = zarr.open(store=zarr.N5Store(r2_path), mode='r')
r6_zarr = zarr.open(store=zarr.N5Store(r6_path), mode='r')
r7_zarr = zarr.open(store=zarr.N5Store(r7_path), mode='r')

r1 = r1_zarr['/c3/s4'][...]
r2 = r2_zarr['/c3/s4'][...]
r6 = r6_zarr['/c3/s4'][...]
r7 = r7_zarr['/c3/s4'][...]

# %%
np.max(r1), np.max(r2), np.max(r6), np.max(r7)
# Out:
# (61957, 47284, 63646, 56672)

# %%
th = np.percentile(r1, 99.9)
r1[r1>th] = th

th = np.percentile(r2, 99.9)
r2[r2>th] = th

th = np.percentile(r6, 99.9)
r6[r6>th] = th

th = np.percentile(r7, 99.9)
r7[r7>th] = th

# %%
np.max(r1), np.max(r2), np.max(r6), np.max(r7)
# Out:
# (167, 239, 192, 178)

# %%
# tifffile.imwrite(outdir+'/r1.tiff', r1)
# tifffile.imwrite(outdir+'/r2.tiff', r2)
# tifffile.imwrite(outdir+'/r6.tiff', r6)
# tifffile.imwrite(outdir+'/r7.tiff', r7)

# %%
mov_path = r2_path
fix_path = r1_path

mov = r2
fix = r1

output_mat = outdir+'/affine_r2tor1.mat'
output_tif = outdir+'/affine_r2tor1.tiff'

# %%
exp_factor = 2  # replace this with the known expansion factor for your sample to use pre-expansion units

s1_scale = [1,2,2] # z,y,x
s3_scale = [4,8,8]
s4_scale = [9,16,16]

# load fix data and spacing
fix_zarr = zarr.open(store=zarr.N5Store(fix_path), mode='r')
fix_meta = fix_zarr.attrs.asdict()
fix_spacing = np.array(fix_meta['pixelResolution']['dimensions'][::-1]) / exp_factor
fix_spacing_s1 = fix_spacing * s1_scale 
fix_spacing_s3 = fix_spacing * s3_scale 
fix_spacing_s4 = fix_spacing * s4_scale 

# load mov data and spacing
mov_zarr = zarr.open(store=zarr.N5Store(mov_path), mode='r')
mov_meta = mov_zarr.attrs.asdict()
mov_spacing = np.array(mov_meta['pixelResolution']['dimensions'][::-1]) / exp_factor
mov_spacing_s1 = mov_spacing * s1_scale
mov_spacing_s3 = mov_spacing * s3_scale 
mov_spacing_s4 = mov_spacing * s4_scale 

# print spacings
print(fix_spacing, mov_spacing)
print(fix_spacing_s1, mov_spacing_s1)
print(fix_spacing_s3, mov_spacing_s3)
print(fix_spacing_s4, mov_spacing_s4)

# print shapes
print(fix_zarr['/c3/s0'].shape, mov_zarr['/c3/s0'].shape)
print(fix_zarr['/c3/s3'].shape, mov_zarr['/c3/s3'].shape)
print(fix_zarr['/c3/s4'].shape, mov_zarr['/c3/s4'].shape)
# Out:
# [0.21  0.115 0.115] [0.21  0.115 0.115]
# [0.21 0.23 0.23] [0.21 0.23 0.23]
# [0.84 0.92 0.92] [0.84 0.92 0.92]
# [1.89 1.84 1.84] [1.89 1.84 1.84]
# (2593, 7309, 9049) (2258, 7348, 9045)
# (648, 913, 1131) (564, 918, 1130)
# (288, 456, 565) (250, 459, 565)

# %% [markdown]
# # Alignment
# ---

# %% [markdown]
# ### global

# %%
# alignment functions
from bigstream.align import alignment_pipeline
from bigstream.transform import apply_transform

# %%
# define alignment steps
ransac_kwargs = {
    'blob_sizes':[2, 8],
    'cc_radius':12,
    'match_threshold':0.4,
    'nspots':10000,
}

affine_kwargs = {
    'alignment_spacing':4.0,
    'shrink_factors':(1,),
    'smooth_sigmas':(4.,),
    'optimizer_args':{
        'learningRate':0.25,
        'minStep':0.,
        'numberOfIterations':400,
    },
    'metric':'C',
}


steps = [
    # ('ransac', ransac_kwargs,),
    ('affine', affine_kwargs,),
]

# %%
# %%time


# align
affine = alignment_pipeline(
    fix, mov,
    fix_spacing_s4,
    mov_spacing_s4,
    steps,
    # fix_mask=fix_mask,
    # mov_mask=mov_mask,
)

# apply affine only
affine_aligned = apply_transform(
    fix, mov,
    fix_spacing_s4, mov_spacing_s4,
    transform_list=[affine,],
)

# write results
np.savetxt(output_mat, affine)
tifffile.imwrite(output_tif, affine_aligned)
# Out:
# LEVEL:  0  ITERATION:  0  METRIC:  -0.1839763854542696
# LEVEL:  0  ITERATION:  1  METRIC:  -0.1872390238066466
# LEVEL:  0  ITERATION:  2  METRIC:  -0.190265265095614
# LEVEL:  0  ITERATION:  3  METRIC:  -0.1930498082819885
# LEVEL:  0  ITERATION:  4  METRIC:  -0.1955875066176842
# LEVEL:  0  ITERATION:  5  METRIC:  -0.1985139312697586
# LEVEL:  0  ITERATION:  6  METRIC:  -0.2004269548591696
# LEVEL:  0  ITERATION:  7  METRIC:  -0.20037928043085515
# LEVEL:  0  ITERATION:  8  METRIC:  -0.2011495454880679
# LEVEL:  0  ITERATION:  9  METRIC:  -0.20179170453053255
# LEVEL:  0  ITERATION:  10  METRIC:  -0.20202076558544813
# LEVEL:  0  ITERATION:  11  METRIC:  -0.20223406485601836
# LEVEL:  0  ITERATION:  12  METRIC:  -0.20286242940968296
# LEVEL:  0  ITERATION:  13  METRIC:  -0.20395682028382878
# LEVEL:  0  ITERATION:  14  METRIC:  -0.2055937552822255
# LEVEL:  0  ITERATION:  15  METRIC:  -0.20752374959125772
# LEVEL:  0  ITERATION:  16  METRIC:  -0.20910235557562262
# LEVEL:  0  ITERATION:  17  METRIC:  -0.21008971004978252
# LEVEL:  0  ITERATION:  18  METRIC:  -0.21023357167400258
# LEVEL:  0  ITERATION:  19  METRIC:  -0.21066616113816541
# LEVEL:  0  ITERATION:  20  METRIC:  -0.21146178265882912
# LEVEL:  0  ITERATION:  21  METRIC:  -0.2123396858672307
# LEVEL:  0  ITERATION:  22  METRIC:  -0.2137194221174981
# LEVEL:  0  ITERATION:  23  METRIC:  -0.21558513235129806
# LEVEL:  0  ITERATION:  24  METRIC:  -0.21778225411358412
# LEVEL:  0  ITERATION:  25  METRIC:  -0.2201672282542398
# LEVEL:  0  ITERATION:  26  METRIC:  -0.22247414688262704
# LEVEL:  0  ITERATION:  27  METRIC:  -0.22441836935620146
# LEVEL:  0  ITERATION:  28  METRIC:  -0.22584164957026343
# LEVEL:  0  ITERATION:  29  METRIC:  -0.22663008353581784
# LEVEL:  0  ITERATION:  30  METRIC:  -0.2277080897861077
# LEVEL:  0  ITERATION:  31  METRIC:  -0.22920327990497652
# LEVEL:  0  ITERATION:  32  METRIC:  -0.23069430163073623
# LEVEL:  0  ITERATION:  33  METRIC:  -0.23213642822390346
# LEVEL:  0  ITERATION:  34  METRIC:  -0.23356647959326146
# LEVEL:  0  ITERATION:  35  METRIC:  -0.235014173329355
# LEVEL:  0  ITERATION:  36  METRIC:  -0.23646893891741813
# LEVEL:  0  ITERATION:  37  METRIC:  -0.23776721747478452
# LEVEL:  0  ITERATION:  38  METRIC:  -0.23892686754422632
# LEVEL:  0  ITERATION:  39  METRIC:  -0.23980658817871442
# LEVEL:  0  ITERATION:  40  METRIC:  -0.24091129229821787
# LEVEL:  0  ITERATION:  41  METRIC:  -0.2425334704530827
# LEVEL:  0  ITERATION:  42  METRIC:  -0.24438770132292895
# LEVEL:  0  ITERATION:  43  METRIC:  -0.2463495130972404
# LEVEL:  0  ITERATION:  44  METRIC:  -0.24815252531852341
# LEVEL:  0  ITERATION:  45  METRIC:  -0.24994080255334877
# LEVEL:  0  ITERATION:  46  METRIC:  -0.25172750255532916
# LEVEL:  0  ITERATION:  47  METRIC:  -0.25353467313289263
# LEVEL:  0  ITERATION:  48  METRIC:  -0.25523028328581876
# LEVEL:  0  ITERATION:  49  METRIC:  -0.2567874416154897
# LEVEL:  0  ITERATION:  50  METRIC:  -0.258640459423537
# LEVEL:  0  ITERATION:  51  METRIC:  -0.2607803906641939
# LEVEL:  0  ITERATION:  52  METRIC:  -0.2629213370372276
# LEVEL:  0  ITERATION:  53  METRIC:  -0.26529731405991996
# LEVEL:  0  ITERATION:  54  METRIC:  -0.26746868426405856
# LEVEL:  0  ITERATION:  55  METRIC:  -0.2694749825627849
# LEVEL:  0  ITERATION:  56  METRIC:  -0.271502660382731
# LEVEL:  0  ITERATION:  57  METRIC:  -0.2734503943126567
# LEVEL:  0  ITERATION:  58  METRIC:  -0.27518909502475397
# LEVEL:  0  ITERATION:  59  METRIC:  -0.2772245054570987
# LEVEL:  0  ITERATION:  60  METRIC:  -0.2795131865839047
# LEVEL:  0  ITERATION:  61  METRIC:  -0.2818658427261676
# LEVEL:  0  ITERATION:  62  METRIC:  -0.28411766529072835
# LEVEL:  0  ITERATION:  63  METRIC:  -0.2864702505410572
# LEVEL:  0  ITERATION:  64  METRIC:  -0.28898518848117427
# LEVEL:  0  ITERATION:  65  METRIC:  -0.2914044024887722
# LEVEL:  0  ITERATION:  66  METRIC:  -0.29358719452430704
# LEVEL:  0  ITERATION:  67  METRIC:  -0.29560430317300945
# LEVEL:  0  ITERATION:  68  METRIC:  -0.2978669604558887
# LEVEL:  0  ITERATION:  69  METRIC:  -0.3004159326050743
# LEVEL:  0  ITERATION:  70  METRIC:  -0.3029726313130838
# LEVEL:  0  ITERATION:  71  METRIC:  -0.3055366928236782
# LEVEL:  0  ITERATION:  72  METRIC:  -0.30812437190775716
# LEVEL:  0  ITERATION:  73  METRIC:  -0.3107550777357785
# LEVEL:  0  ITERATION:  74  METRIC:  -0.31353936329306914
# LEVEL:  0  ITERATION:  75  METRIC:  -0.31616806507748246
# LEVEL:  0  ITERATION:  76  METRIC:  -0.31848248118306016
# LEVEL:  0  ITERATION:  77  METRIC:  -0.3208423205731888
# LEVEL:  0  ITERATION:  78  METRIC:  -0.3234309417843206
# LEVEL:  0  ITERATION:  79  METRIC:  -0.326136177369914
# LEVEL:  0  ITERATION:  80  METRIC:  -0.3288950298054453
# LEVEL:  0  ITERATION:  81  METRIC:  -0.331490256042908
# LEVEL:  0  ITERATION:  82  METRIC:  -0.3340340196347652
# LEVEL:  0  ITERATION:  83  METRIC:  -0.33663988220711744
# LEVEL:  0  ITERATION:  84  METRIC:  -0.33923837208904906
# LEVEL:  0  ITERATION:  85  METRIC:  -0.3419312563605194
# LEVEL:  0  ITERATION:  86  METRIC:  -0.344478003976565
# LEVEL:  0  ITERATION:  87  METRIC:  -0.3469000325049794
# LEVEL:  0  ITERATION:  88  METRIC:  -0.3494572816163083
# LEVEL:  0  ITERATION:  89  METRIC:  -0.3520646487288925
# LEVEL:  0  ITERATION:  90  METRIC:  -0.35469256371240593
# LEVEL:  0  ITERATION:  91  METRIC:  -0.3572388736277355
# LEVEL:  0  ITERATION:  92  METRIC:  -0.3595695189321901
# LEVEL:  0  ITERATION:  93  METRIC:  -0.36171831508554303
# LEVEL:  0  ITERATION:  94  METRIC:  -0.3639703296375647
# LEVEL:  0  ITERATION:  95  METRIC:  -0.3663246783617689
# LEVEL:  0  ITERATION:  96  METRIC:  -0.3689879715119937
# LEVEL:  0  ITERATION:  97  METRIC:  -0.3714343766274253
# LEVEL:  0  ITERATION:  98  METRIC:  -0.3736573308843816
# LEVEL:  0  ITERATION:  99  METRIC:  -0.37586681329719135
# LEVEL:  0  ITERATION:  100  METRIC:  -0.3780848143139771
# LEVEL:  0  ITERATION:  101  METRIC:  -0.38019291446168346
# LEVEL:  0  ITERATION:  102  METRIC:  -0.38217248287878697
# LEVEL:  0  ITERATION:  103  METRIC:  -0.38402600131064585
# LEVEL:  0  ITERATION:  104  METRIC:  -0.38582222313538106
# LEVEL:  0  ITERATION:  105  METRIC:  -0.3876186601222429
# LEVEL:  0  ITERATION:  106  METRIC:  -0.3894932230411241
# LEVEL:  0  ITERATION:  107  METRIC:  -0.3915093462917784
# LEVEL:  0  ITERATION:  108  METRIC:  -0.39359607467618923
# LEVEL:  0  ITERATION:  109  METRIC:  -0.39564927873322225
# LEVEL:  0  ITERATION:  110  METRIC:  -0.3975436671316059
# LEVEL:  0  ITERATION:  111  METRIC:  -0.3993590085545851
# LEVEL:  0  ITERATION:  112  METRIC:  -0.4011681088149963
# LEVEL:  0  ITERATION:  113  METRIC:  -0.40298652903497023
# LEVEL:  0  ITERATION:  114  METRIC:  -0.4046829960608702
# LEVEL:  0  ITERATION:  115  METRIC:  -0.40635956310586074
# LEVEL:  0  ITERATION:  116  METRIC:  -0.4079737550123806
# LEVEL:  0  ITERATION:  117  METRIC:  -0.4094997046380581
# LEVEL:  0  ITERATION:  118  METRIC:  -0.4109903791516687
# LEVEL:  0  ITERATION:  119  METRIC:  -0.4125047551969357
# LEVEL:  0  ITERATION:  120  METRIC:  -0.41413959186687077
# LEVEL:  0  ITERATION:  121  METRIC:  -0.41584317199275345
# LEVEL:  0  ITERATION:  122  METRIC:  -0.4177101098697406
# LEVEL:  0  ITERATION:  123  METRIC:  -0.4195718017838433
# LEVEL:  0  ITERATION:  124  METRIC:  -0.4213613300766717
# LEVEL:  0  ITERATION:  125  METRIC:  -0.4229254249745002
# LEVEL:  0  ITERATION:  126  METRIC:  -0.42442799803835946
# LEVEL:  0  ITERATION:  127  METRIC:  -0.425976587052985
# LEVEL:  0  ITERATION:  128  METRIC:  -0.4275504986012445
# LEVEL:  0  ITERATION:  129  METRIC:  -0.42910974324700346
# LEVEL:  0  ITERATION:  130  METRIC:  -0.43069171652724925
# LEVEL:  0  ITERATION:  131  METRIC:  -0.4322815432968138
# LEVEL:  0  ITERATION:  132  METRIC:  -0.4339211988601153
# LEVEL:  0  ITERATION:  133  METRIC:  -0.43557585723676545
# LEVEL:  0  ITERATION:  134  METRIC:  -0.4372821882790386
# LEVEL:  0  ITERATION:  135  METRIC:  -0.4390040889022597
# LEVEL:  0  ITERATION:  136  METRIC:  -0.44072333424319393
# LEVEL:  0  ITERATION:  137  METRIC:  -0.44244711486094235
# LEVEL:  0  ITERATION:  138  METRIC:  -0.4441978889765542
# LEVEL:  0  ITERATION:  139  METRIC:  -0.44599144845681643
# LEVEL:  0  ITERATION:  140  METRIC:  -0.4478299895508477
# LEVEL:  0  ITERATION:  141  METRIC:  -0.4497320367511202
# LEVEL:  0  ITERATION:  142  METRIC:  -0.45168147350991217
# LEVEL:  0  ITERATION:  143  METRIC:  -0.45369735173185477
# LEVEL:  0  ITERATION:  144  METRIC:  -0.4557923266169847
# LEVEL:  0  ITERATION:  145  METRIC:  -0.4578756863117047
# LEVEL:  0  ITERATION:  146  METRIC:  -0.45993704993616724
# LEVEL:  0  ITERATION:  147  METRIC:  -0.46199347153426384
# LEVEL:  0  ITERATION:  148  METRIC:  -0.46404534140171366
# LEVEL:  0  ITERATION:  149  METRIC:  -0.4661092566658514
# LEVEL:  0  ITERATION:  150  METRIC:  -0.46817144225040924
# LEVEL:  0  ITERATION:  151  METRIC:  -0.47025924368981065
# LEVEL:  0  ITERATION:  152  METRIC:  -0.4723420957775268
# LEVEL:  0  ITERATION:  153  METRIC:  -0.4744177284965743
# LEVEL:  0  ITERATION:  154  METRIC:  -0.47649037900343155
# LEVEL:  0  ITERATION:  155  METRIC:  -0.4785529785263013
# LEVEL:  0  ITERATION:  156  METRIC:  -0.4805996235174468
# LEVEL:  0  ITERATION:  157  METRIC:  -0.48262144260133555
# LEVEL:  0  ITERATION:  158  METRIC:  -0.48461217889949443
# LEVEL:  0  ITERATION:  159  METRIC:  -0.4865612535177424
# LEVEL:  0  ITERATION:  160  METRIC:  -0.48850796244453565
# LEVEL:  0  ITERATION:  161  METRIC:  -0.49041032671315316
# LEVEL:  0  ITERATION:  162  METRIC:  -0.4922789594272159
# LEVEL:  0  ITERATION:  163  METRIC:  -0.49409915411290867
# LEVEL:  0  ITERATION:  164  METRIC:  -0.4958490625636952
# LEVEL:  0  ITERATION:  165  METRIC:  -0.4975344861433166
# LEVEL:  0  ITERATION:  166  METRIC:  -0.4991941659371301
# LEVEL:  0  ITERATION:  167  METRIC:  -0.5008381848026318
# LEVEL:  0  ITERATION:  168  METRIC:  -0.5024918096811486
# LEVEL:  0  ITERATION:  169  METRIC:  -0.504148076859558
# LEVEL:  0  ITERATION:  170  METRIC:  -0.505783116265012
# LEVEL:  0  ITERATION:  171  METRIC:  -0.5074582865335311
# LEVEL:  0  ITERATION:  172  METRIC:  -0.5091407947518677
# LEVEL:  0  ITERATION:  173  METRIC:  -0.5108362226724176
# LEVEL:  0  ITERATION:  174  METRIC:  -0.5125146612684776
# LEVEL:  0  ITERATION:  175  METRIC:  -0.5141643253842605
# LEVEL:  0  ITERATION:  176  METRIC:  -0.5157885757079177
# LEVEL:  0  ITERATION:  177  METRIC:  -0.5174171953543719
# LEVEL:  0  ITERATION:  178  METRIC:  -0.5190567415135512
# LEVEL:  0  ITERATION:  179  METRIC:  -0.5207372915256191
# LEVEL:  0  ITERATION:  180  METRIC:  -0.5224341136949917
# LEVEL:  0  ITERATION:  181  METRIC:  -0.5241258615195692
# LEVEL:  0  ITERATION:  182  METRIC:  -0.5258347079781694
# LEVEL:  0  ITERATION:  183  METRIC:  -0.5275024470252073
# LEVEL:  0  ITERATION:  184  METRIC:  -0.5291123529784987
# LEVEL:  0  ITERATION:  185  METRIC:  -0.5306907038119839
# LEVEL:  0  ITERATION:  186  METRIC:  -0.5322507885980676
# LEVEL:  0  ITERATION:  187  METRIC:  -0.5337812763422967
# LEVEL:  0  ITERATION:  188  METRIC:  -0.5352969682882763
# LEVEL:  0  ITERATION:  189  METRIC:  -0.5367977654952337
# LEVEL:  0  ITERATION:  190  METRIC:  -0.5382802610770723
# LEVEL:  0  ITERATION:  191  METRIC:  -0.5397547938945652
# LEVEL:  0  ITERATION:  192  METRIC:  -0.5412159589707193
# LEVEL:  0  ITERATION:  193  METRIC:  -0.5426733576112659
# LEVEL:  0  ITERATION:  194  METRIC:  -0.5441112079920719
# LEVEL:  0  ITERATION:  195  METRIC:  -0.5455389819309705
# LEVEL:  0  ITERATION:  196  METRIC:  -0.5469744622636459
# LEVEL:  0  ITERATION:  197  METRIC:  -0.5484222751767699
# LEVEL:  0  ITERATION:  198  METRIC:  -0.5498640973297756
# LEVEL:  0  ITERATION:  199  METRIC:  -0.5513028299797758
# LEVEL:  0  ITERATION:  200  METRIC:  -0.5527334369834933
# LEVEL:  0  ITERATION:  201  METRIC:  -0.5541244266116316
# LEVEL:  0  ITERATION:  202  METRIC:  -0.5554874984411063
# LEVEL:  0  ITERATION:  203  METRIC:  -0.5568142098652886
# LEVEL:  0  ITERATION:  204  METRIC:  -0.5581272629619796
# LEVEL:  0  ITERATION:  205  METRIC:  -0.5594217029724964
# LEVEL:  0  ITERATION:  206  METRIC:  -0.5607080113721409
# LEVEL:  0  ITERATION:  207  METRIC:  -0.561989396237132
# LEVEL:  0  ITERATION:  208  METRIC:  -0.5632708665345532
# LEVEL:  0  ITERATION:  209  METRIC:  -0.5645989164838519
# LEVEL:  0  ITERATION:  210  METRIC:  -0.5659811179624381
# LEVEL:  0  ITERATION:  211  METRIC:  -0.5673429682709257
# LEVEL:  0  ITERATION:  212  METRIC:  -0.5686890514055206
# LEVEL:  0  ITERATION:  213  METRIC:  -0.5699887140664985
# LEVEL:  0  ITERATION:  214  METRIC:  -0.5713003031117624
# LEVEL:  0  ITERATION:  215  METRIC:  -0.572547878988332
# LEVEL:  0  ITERATION:  216  METRIC:  -0.5737602447960863
# LEVEL:  0  ITERATION:  217  METRIC:  -0.5749864668428627
# LEVEL:  0  ITERATION:  218  METRIC:  -0.5761937705776295
# LEVEL:  0  ITERATION:  219  METRIC:  -0.5773749406212232
# LEVEL:  0  ITERATION:  220  METRIC:  -0.5785414148739538
# LEVEL:  0  ITERATION:  221  METRIC:  -0.5796955970819552
# LEVEL:  0  ITERATION:  222  METRIC:  -0.5808090940148284
# LEVEL:  0  ITERATION:  223  METRIC:  -0.5819534643782062
# LEVEL:  0  ITERATION:  224  METRIC:  -0.5830833373939769
# LEVEL:  0  ITERATION:  225  METRIC:  -0.5842136820199166
# LEVEL:  0  ITERATION:  226  METRIC:  -0.585373983735774
# LEVEL:  0  ITERATION:  227  METRIC:  -0.5865130739837513
# LEVEL:  0  ITERATION:  228  METRIC:  -0.5876715010359075
# LEVEL:  0  ITERATION:  229  METRIC:  -0.5888132591972676
# LEVEL:  0  ITERATION:  230  METRIC:  -0.5899487152796459
# LEVEL:  0  ITERATION:  231  METRIC:  -0.5911042366896058
# LEVEL:  0  ITERATION:  232  METRIC:  -0.5922433222330297
# LEVEL:  0  ITERATION:  233  METRIC:  -0.5934315184823202
# LEVEL:  0  ITERATION:  234  METRIC:  -0.5946386729518922
# LEVEL:  0  ITERATION:  235  METRIC:  -0.5958693233058889
# LEVEL:  0  ITERATION:  236  METRIC:  -0.5971310940714466
# LEVEL:  0  ITERATION:  237  METRIC:  -0.5983919241123862
# LEVEL:  0  ITERATION:  238  METRIC:  -0.5996359810143497
# LEVEL:  0  ITERATION:  239  METRIC:  -0.6008834594724477
# LEVEL:  0  ITERATION:  240  METRIC:  -0.6021289222249298
# LEVEL:  0  ITERATION:  241  METRIC:  -0.6033688993760646
# LEVEL:  0  ITERATION:  242  METRIC:  -0.6045801869013315
# LEVEL:  0  ITERATION:  243  METRIC:  -0.6057361398887574
# LEVEL:  0  ITERATION:  244  METRIC:  -0.6068909409628473
# LEVEL:  0  ITERATION:  245  METRIC:  -0.6079906514940553
# LEVEL:  0  ITERATION:  246  METRIC:  -0.6090961577507463
# LEVEL:  0  ITERATION:  247  METRIC:  -0.6101832339438329
# LEVEL:  0  ITERATION:  248  METRIC:  -0.6112642410414262
# LEVEL:  0  ITERATION:  249  METRIC:  -0.6123371561413732
# LEVEL:  0  ITERATION:  250  METRIC:  -0.6133926025546151
# LEVEL:  0  ITERATION:  251  METRIC:  -0.6144447197814049
# LEVEL:  0  ITERATION:  252  METRIC:  -0.615488077786152
# LEVEL:  0  ITERATION:  253  METRIC:  -0.6165384684831715
# LEVEL:  0  ITERATION:  254  METRIC:  -0.6175848166819007
# LEVEL:  0  ITERATION:  255  METRIC:  -0.6186282152227734
# LEVEL:  0  ITERATION:  256  METRIC:  -0.6196919951498718
# LEVEL:  0  ITERATION:  257  METRIC:  -0.6207689252363979
# LEVEL:  0  ITERATION:  258  METRIC:  -0.6218774813272498
# LEVEL:  0  ITERATION:  259  METRIC:  -0.6229913098751125
# LEVEL:  0  ITERATION:  260  METRIC:  -0.6241237367476205
# LEVEL:  0  ITERATION:  261  METRIC:  -0.6252693992709654
# LEVEL:  0  ITERATION:  262  METRIC:  -0.6264110016747828
# LEVEL:  0  ITERATION:  263  METRIC:  -0.6275469886429657
# LEVEL:  0  ITERATION:  264  METRIC:  -0.6286855970177962
# LEVEL:  0  ITERATION:  265  METRIC:  -0.6298070133527185
# LEVEL:  0  ITERATION:  266  METRIC:  -0.6309327722285151
# LEVEL:  0  ITERATION:  267  METRIC:  -0.6320522955181834
# LEVEL:  0  ITERATION:  268  METRIC:  -0.6331655085868448
# LEVEL:  0  ITERATION:  269  METRIC:  -0.6342516755804369
# LEVEL:  0  ITERATION:  270  METRIC:  -0.6353500862353626
# LEVEL:  0  ITERATION:  271  METRIC:  -0.6364272149120043
# LEVEL:  0  ITERATION:  272  METRIC:  -0.6374936835625341
# LEVEL:  0  ITERATION:  273  METRIC:  -0.638534081147489
# LEVEL:  0  ITERATION:  274  METRIC:  -0.6395730350774614
# LEVEL:  0  ITERATION:  275  METRIC:  -0.6405981588595452
# LEVEL:  0  ITERATION:  276  METRIC:  -0.6416186400414529
# LEVEL:  0  ITERATION:  277  METRIC:  -0.6426309985621537
# LEVEL:  0  ITERATION:  278  METRIC:  -0.6436400135826053
# LEVEL:  0  ITERATION:  279  METRIC:  -0.6446585358516331
# LEVEL:  0  ITERATION:  280  METRIC:  -0.6456791049578922
# LEVEL:  0  ITERATION:  281  METRIC:  -0.6467119604354078
# LEVEL:  0  ITERATION:  282  METRIC:  -0.6477531166979505
# LEVEL:  0  ITERATION:  283  METRIC:  -0.6488132706351617
# LEVEL:  0  ITERATION:  284  METRIC:  -0.649884447273495
# LEVEL:  0  ITERATION:  285  METRIC:  -0.6509621476079529
# LEVEL:  0  ITERATION:  286  METRIC:  -0.6520426768905067
# LEVEL:  0  ITERATION:  287  METRIC:  -0.6531253863425494
# LEVEL:  0  ITERATION:  288  METRIC:  -0.6542021209557599
# LEVEL:  0  ITERATION:  289  METRIC:  -0.6552820600983981
# LEVEL:  0  ITERATION:  290  METRIC:  -0.6563544689222116
# LEVEL:  0  ITERATION:  291  METRIC:  -0.6574290210732755
# LEVEL:  0  ITERATION:  292  METRIC:  -0.6584965694881991
# LEVEL:  0  ITERATION:  293  METRIC:  -0.6595611545867177
# LEVEL:  0  ITERATION:  294  METRIC:  -0.66060336503193
# LEVEL:  0  ITERATION:  295  METRIC:  -0.6616421225661109
# LEVEL:  0  ITERATION:  296  METRIC:  -0.6626824325933266
# LEVEL:  0  ITERATION:  297  METRIC:  -0.6637082180959476
# LEVEL:  0  ITERATION:  298  METRIC:  -0.6647244223585681
# LEVEL:  0  ITERATION:  299  METRIC:  -0.6657204363021401
# LEVEL:  0  ITERATION:  300  METRIC:  -0.6667129361833429
# LEVEL:  0  ITERATION:  301  METRIC:  -0.6676864785178523
# LEVEL:  0  ITERATION:  302  METRIC:  -0.6686495331582629
# LEVEL:  0  ITERATION:  303  METRIC:  -0.6696068416706186
# LEVEL:  0  ITERATION:  304  METRIC:  -0.6705491975725405
# LEVEL:  0  ITERATION:  305  METRIC:  -0.671486118691894
# LEVEL:  0  ITERATION:  306  METRIC:  -0.672415703962159
# LEVEL:  0  ITERATION:  307  METRIC:  -0.6733486295486708
# LEVEL:  0  ITERATION:  308  METRIC:  -0.6742890936621869
# LEVEL:  0  ITERATION:  309  METRIC:  -0.6752284406482562
# LEVEL:  0  ITERATION:  310  METRIC:  -0.6761800242189098
# LEVEL:  0  ITERATION:  311  METRIC:  -0.6771239741776164
# LEVEL:  0  ITERATION:  312  METRIC:  -0.6780691348772121
# LEVEL:  0  ITERATION:  313  METRIC:  -0.6790344233935147
# LEVEL:  0  ITERATION:  314  METRIC:  -0.6799647723866373
# LEVEL:  0  ITERATION:  315  METRIC:  -0.6809030491851527
# LEVEL:  0  ITERATION:  316  METRIC:  -0.6818508649648184
# LEVEL:  0  ITERATION:  317  METRIC:  -0.6827729019088714
# LEVEL:  0  ITERATION:  318  METRIC:  -0.6836985139355396
# LEVEL:  0  ITERATION:  319  METRIC:  -0.684606671974139
# LEVEL:  0  ITERATION:  320  METRIC:  -0.6855071626245877
# LEVEL:  0  ITERATION:  321  METRIC:  -0.6863928495562489
# LEVEL:  0  ITERATION:  322  METRIC:  -0.6872673469251335
# LEVEL:  0  ITERATION:  323  METRIC:  -0.6881237017289183
# LEVEL:  0  ITERATION:  324  METRIC:  -0.6889623943423915
# LEVEL:  0  ITERATION:  325  METRIC:  -0.689791593231529
# LEVEL:  0  ITERATION:  326  METRIC:  -0.6906088164656154
# LEVEL:  0  ITERATION:  327  METRIC:  -0.6914189108726189
# LEVEL:  0  ITERATION:  328  METRIC:  -0.6922201308250552
# LEVEL:  0  ITERATION:  329  METRIC:  -0.693020753095854
# LEVEL:  0  ITERATION:  330  METRIC:  -0.6938133167597618
# LEVEL:  0  ITERATION:  331  METRIC:  -0.6946044319147233
# LEVEL:  0  ITERATION:  332  METRIC:  -0.6953947877565216
# LEVEL:  0  ITERATION:  333  METRIC:  -0.6961814378014631
# LEVEL:  0  ITERATION:  334  METRIC:  -0.6969609403250494
# LEVEL:  0  ITERATION:  335  METRIC:  -0.697736029549875
# LEVEL:  0  ITERATION:  336  METRIC:  -0.6985119771161014
# LEVEL:  0  ITERATION:  337  METRIC:  -0.6992736821347434
# LEVEL:  0  ITERATION:  338  METRIC:  -0.7000283931843901
# LEVEL:  0  ITERATION:  339  METRIC:  -0.7007686435083113
# LEVEL:  0  ITERATION:  340  METRIC:  -0.7014899841355628
# LEVEL:  0  ITERATION:  341  METRIC:  -0.7022013369560871
# LEVEL:  0  ITERATION:  342  METRIC:  -0.7029082096805944
# LEVEL:  0  ITERATION:  343  METRIC:  -0.7036038920048885
# LEVEL:  0  ITERATION:  344  METRIC:  -0.7042811021189034
# LEVEL:  0  ITERATION:  345  METRIC:  -0.7049451039565846
# LEVEL:  0  ITERATION:  346  METRIC:  -0.7056019328706424
# LEVEL:  0  ITERATION:  347  METRIC:  -0.7062545894221133
# LEVEL:  0  ITERATION:  348  METRIC:  -0.7068833687424193
# LEVEL:  0  ITERATION:  349  METRIC:  -0.7074896202174101
# LEVEL:  0  ITERATION:  350  METRIC:  -0.708081473682804
# LEVEL:  0  ITERATION:  351  METRIC:  -0.7086581695886264
# LEVEL:  0  ITERATION:  352  METRIC:  -0.7092172216408119
# LEVEL:  0  ITERATION:  353  METRIC:  -0.7097760169090119
# LEVEL:  0  ITERATION:  354  METRIC:  -0.7103069835666223
# LEVEL:  0  ITERATION:  355  METRIC:  -0.7108466833623854
# LEVEL:  0  ITERATION:  356  METRIC:  -0.7113246973100812
# LEVEL:  0  ITERATION:  357  METRIC:  -0.7118783217274676
# LEVEL:  0  ITERATION:  358  METRIC:  -0.7121470126337998
# LEVEL:  0  ITERATION:  359  METRIC:  -0.7127841589773122
# LEVEL:  0  ITERATION:  360  METRIC:  -0.7127493000811207
# LEVEL:  0  ITERATION:  361  METRIC:  -0.7130531436661434
# LEVEL:  0  ITERATION:  362  METRIC:  -0.7132263942313325
# LEVEL:  0  ITERATION:  363  METRIC:  -0.7134989348716521
# LEVEL:  0  ITERATION:  364  METRIC:  -0.7136914172631998
# LEVEL:  0  ITERATION:  365  METRIC:  -0.7139576130770791
# LEVEL:  0  ITERATION:  366  METRIC:  -0.7141458184451531
# LEVEL:  0  ITERATION:  367  METRIC:  -0.714403776866225
# LEVEL:  0  ITERATION:  368  METRIC:  -0.7145945622960981
# LEVEL:  0  ITERATION:  369  METRIC:  -0.7148499362875744
# LEVEL:  0  ITERATION:  370  METRIC:  -0.7150254452517993
# LEVEL:  0  ITERATION:  371  METRIC:  -0.7152863124768348
# LEVEL:  0  ITERATION:  372  METRIC:  -0.7154384260982627
# LEVEL:  0  ITERATION:  373  METRIC:  -0.7157116345499674
# LEVEL:  0  ITERATION:  374  METRIC:  -0.715814765596895
# LEVEL:  0  ITERATION:  375  METRIC:  -0.7160968497614687
# LEVEL:  0  ITERATION:  376  METRIC:  -0.7161444832258099
# LEVEL:  0  ITERATION:  377  METRIC:  -0.7164417868231653
# LEVEL:  0  ITERATION:  378  METRIC:  -0.7164485552258764
# LEVEL:  0  ITERATION:  379  METRIC:  -0.7167440737619318
# LEVEL:  0  ITERATION:  380  METRIC:  -0.7167215709334916
# LEVEL:  0  ITERATION:  381  METRIC:  -0.7170160496153658
# LEVEL:  0  ITERATION:  382  METRIC:  -0.7169782327465345
# LEVEL:  0  ITERATION:  383  METRIC:  -0.7172704724560651
# LEVEL:  0  ITERATION:  384  METRIC:  -0.7172602541590886
# LEVEL:  0  ITERATION:  385  METRIC:  -0.7173513838120511
# LEVEL:  0  ITERATION:  386  METRIC:  -0.7174332657903816
# LEVEL:  0  ITERATION:  387  METRIC:  -0.7175170744144987
# LEVEL:  0  ITERATION:  388  METRIC:  -0.717597298039677
# LEVEL:  0  ITERATION:  389  METRIC:  -0.717680775083606
# LEVEL:  0  ITERATION:  390  METRIC:  -0.717761207244643
# LEVEL:  0  ITERATION:  391  METRIC:  -0.7178364321648749
# LEVEL:  0  ITERATION:  392  METRIC:  -0.7179114796752265
# LEVEL:  0  ITERATION:  393  METRIC:  -0.7179882098720177
# LEVEL:  0  ITERATION:  394  METRIC:  -0.7180638220558593
# LEVEL:  0  ITERATION:  395  METRIC:  -0.7181402710010659
# LEVEL:  0  ITERATION:  396  METRIC:  -0.7182124179387468
# LEVEL:  0  ITERATION:  397  METRIC:  -0.7182743714090969
# LEVEL:  0  ITERATION:  398  METRIC:  -0.7183453609120191
# LEVEL:  0  ITERATION:  399  METRIC:  -0.7184164236220278
# Registration succeeded
# CPU times: user 30min 53s, sys: 9.99 s, total: 31min 3s
# Wall time: 4min 25s

# %%
affine[:3,3]
# Out:
# array([-86.86985687,  -9.44812301,  13.67613906])

# %%
sns.heatmap(affine[:3,:3] - np.eye(3))
plt.show()
sns.heatmap(affine[:3, 3].reshape(-1,1))
plt.show()
